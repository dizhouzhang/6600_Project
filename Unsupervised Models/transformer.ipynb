# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("train.csv")
df2 = pd.read_csv("test.csv")
df= df.drop(columns="Unnamed: 0")
df
# Out:
#       Policy_start_date  Age  Annual_premium  Vehicle_year  Claim_amount  \
# 0            2013-11-29   38          380.20          2013           0.0
# 1            2013-11-29   38          393.50          2013           0.0
# 2            2013-11-29   38          393.50          2013           0.0
# 3            2013-11-29   38          395.47          2013           0.0
# 4            2006-05-29   39          250.52          2006           0.0
# ...                 ...  ...             ...           ...           ...
# 97048        2018-07-30   37          263.79          2000           0.0
# 97049        2018-08-16   41          418.97          2013           0.0
# 97050        2018-11-21   44          571.91          1999           0.0
# 97051        2018-11-21   72          339.66          2004           0.0
# 97052        2018-10-01   45          447.12          2010           0.0
#
#        Vehicle_risk_type  Area
# 0                      2     0
# 1                      2     0
# 2                      2     0
# 3                      2     0
# 4                      2     0
# ...                  ...   ...
# 97048                  2     0
# 97049                  2     0
# 97050                  2     0
# 97051                  1     0
# 97052                  2     0
#
# [97053 rows x 7 columns]

# %%
df.loc[0, "Annual_premium"]
from datetime import datetime

date_str = "2014-01-01"
year = datetime.strptime(date_str, "%Y-%m-%d").year  # Extract the year
print(year)
# Out:
# 2014

# %%
df_cleaned = df
for x in range(df_cleaned.shape[0]):
    date_str = df_cleaned.loc[x,"Policy_start_date"]
    year = datetime.strptime(date_str, "%Y-%m-%d").year
    df_cleaned.loc[x,"Policy_start_date"] = year
    age = int(df_cleaned.loc[x,"Age"])
    if age < 10:
        df_cleaned.loc[x, "Age"] = "<10"
    else:
        for start in range(10, 100, 10):
            if start <= age < start + 10:
                df_cleaned.loc[x, "Age"] = f"{start}-{start + 10}"
                break
        else:
            df_cleaned.loc[x, "Age"] = "90-100"
    ap = df_cleaned.loc[x,"Annual_premium"]
    #print(ap)
    if ap < 100:
        df_cleaned.loc[x, "Annual_premium"] = "ap<100"
    else:
        for start in range(100, 2000, 100):
            if start <= ap < start + 100:
                df_cleaned.loc[x, "Annual_premium"] = f"ap{start}-{start + 100}"
                break
        else:
            df_cleaned.loc[x, "Annual_premium"] = "ap1900-2000"
    claims = df_cleaned.loc[x,"Claim_amount"]
    if claims<1000:
        df_cleaned.loc[x,"Claim_amount"] = "<1000"
    elif claims < 5000:
        df_cleaned.loc[x,"Claim_amount"] = "1000<5000"
    elif claims < 10000:
        df_cleaned.loc[x,"Claim_amount"] = "5000<10000"
    elif claims < 50000:
        df_cleaned.loc[x,"Claim_amount"] = "10000<50000"
    else:
        df_cleaned.loc[x,"Claim_amount"] = "50000+"
# Out:
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/3361145437.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30-40' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_cleaned.loc[x, "Age"] = f"{start}-{start + 10}"
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/3361145437.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ap300-400' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_cleaned.loc[x, "Annual_premium"] = f"ap{start}-{start + 100}"
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/3361145437.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<1000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_cleaned.loc[x,"Claim_amount"] = "<1000"

# %%
df_cleaned["Claim_amount"].unique().max()
# Out:
# 260853.24

# %%
import torch
import tensorflow as tf
import pandas as pd
import numpy as np
df = df_cleaned
col1 = ['Policy_start_date', 'Age', 'Annual_premium', 'Vehicle_year',
       'Claim_amount', 'Vehicle_risk_type', 'Area']
from collections import defaultdict#run once
data_whole = []
for x in range(df.shape[0]):#df.shape[0]):
    ls0=[]
    for k in col1:
        v = df.loc[x,k]
        #if(isinstance(v,str)):
        v=str(v)
        ls0.append(v)
    data_whole.append(ls0)
data_whole = np.array(data_whole)
ustring = np.unique(data_whole.flatten())
ustring.shape
dict = {string: idx for idx, string in enumerate(ustring)}
len(dict)
print(dict.get("10225.0"))
dict_id = {v: k for k, v in dict.items()}
print(dict_id.get(110))
print(len(dict))
# Out:
# None
# None
# 98

# %%
num_heads = 8#run once
d_model = 512
ff_dim = 2048
batch_size, seq_len, d_model = 32, 50, 512
num_classes = 512
vocab_size = len(dict)
num_layers = 3
class transformer(torch.nn.Module):
    def __init__(self,vocab_size, d_model, num_heads, ff_dim, num_layers):
        super(transformer, self).__init__()
        self.embedding = torch.nn.Embedding(vocab_size, d_model)
        #self.positional_encoding = torch.nn.Parameter(torch.zeros(1, vocab_size, d_model))
        self.transf = torch.nn.Transformer(d_model, num_heads, num_layers, num_layers, ff_dim, batch_first=True)
        self.ffn = torch.nn.Linear(d_model, vocab_size) #torch.nn.Linear(ff_dim, d_model),
        # self.norm1 = torch.nn.LayerNorm(d_model)
        # self.norm2 = torch.nn.LayerNorm(d_model)
        #self.onedim = torch.nn.Linear(d_model)
        #self.softmax = torch.nn.Softmax()

    def forward(self, x):
        x = self.embedding(x) #+ self.positional_encoding[:, :x.size(1), :]
        output = self.transf(x, x)
        logits = self.ffn(output)
        return logits
    def pred(self,x):
        #embedded_vocab = self.embedding.weight
        #probabilities = torch.nn.functional.softmax(x.float(),dim=-1)
        return torch.argmax(x, dim=-1)
    def return_embed(self):
        return self.embedding.weight
tfm = transformer(vocab_size, d_model, num_heads, ff_dim, num_layers)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(tfm.parameters(), lr=1e-3)

# %%
total_rows = df_cleaned.shape[0]
import random
batch_size = 512
epochs = 0
for kv in range(4):
  ls_loss0 = []
  random.shuffle(col1)
  print(col1)
  for batch_start in range(0, total_rows, batch_size):
      batch_end = min(batch_start + batch_size, total_rows)
      str_ls = []
      for x in range(batch_start, batch_end):
          ls0 = []
          for col in col1:
            v = df.loc[x, col]
            v = str(v)
            ls0.append(v)
          str_ls.append(ls0)
      data_x = np.array(str_ls)
      print(f"Processing batch from row {batch_start} to {batch_end}: {data_x.shape}")

      x_train = []
      for row in str_ls:
          ls0 = []
          for item in row:
              ls0.append(dict.get(item, 0))
          x_train.append(ls0)

      x_train = torch.from_numpy(np.array(x_train))
      y_train = x_train[:, 1:]
      x_train = x_train[:, :-1]

      ls_loss = 0
      output = tfm(x_train)
      output = output.view(-1, output.size(-1))
      #print(output.shape)
      #print(y_train.shape)
      y_batch = y_train.reshape(-1)
      #print(y_batch.shape)
      loss = criterion(output,y_batch)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      ls_loss=loss.item()
      print("Epochs: ",epochs,"Loss: ",ls_loss)
      ls_loss0.append(ls_loss)
  epochs+=1
  print("loss mean: ", sum(ls_loss0) / len(ls_loss0))
  torch.save(tfm.state_dict(), "transformer_model_no_positional_1.pth")
# Out:
# ['Annual_premium', 'Area', 'Age', 'Vehicle_year', 'Vehicle_risk_type', 'Claim_amount', 'Policy_start_date']
# Processing batch from row 0 to 512: (512, 7)
# Epochs:  0 Loss:  3.4826724529266357
# Processing batch from row 512 to 1024: (512, 7)
# Epochs:  0 Loss:  3.625688314437866
# Processing batch from row 1024 to 1536: (512, 7)
# Epochs:  0 Loss:  3.4156782627105713
# Processing batch from row 1536 to 2048: (512, 7)
# Epochs:  0 Loss:  3.345763921737671
# Processing batch from row 2048 to 2560: (512, 7)
# Epochs:  0 Loss:  3.3733081817626953
# Processing batch from row 2560 to 3072: (512, 7)
# Epochs:  0 Loss:  3.332897901535034
# Processing batch from row 3072 to 3584: (512, 7)
# Epochs:  0 Loss:  3.451181650161743
# Processing batch from row 3584 to 4096: (512, 7)
# Epochs:  0 Loss:  3.2608747482299805
# Processing batch from row 4096 to 4608: (512, 7)
# Epochs:  0 Loss:  3.1796200275421143
# Processing batch from row 4608 to 5120: (512, 7)
# Epochs:  0 Loss:  3.1496593952178955
# Processing batch from row 5120 to 5632: (512, 7)
# Epochs:  0 Loss:  3.2072269916534424
# Processing batch from row 5632 to 6144: (512, 7)
# Epochs:  0 Loss:  3.1715610027313232
# Processing batch from row 6144 to 6656: (512, 7)
# Epochs:  0 Loss:  3.2285783290863037
# Processing batch from row 6656 to 7168: (512, 7)
# Epochs:  0 Loss:  3.060784339904785
# Processing batch from row 7168 to 7680: (512, 7)
# Epochs:  0 Loss:  3.0545661449432373
# Processing batch from row 7680 to 8192: (512, 7)
# Epochs:  0 Loss:  3.0186054706573486
# Processing batch from row 8192 to 8704: (512, 7)
# Epochs:  0 Loss:  3.0469071865081787
# Processing batch from row 8704 to 9216: (512, 7)
# Epochs:  0 Loss:  3.0506277084350586
# Processing batch from row 9216 to 9728: (512, 7)
# Epochs:  0 Loss:  3.0862677097320557
# Processing batch from row 9728 to 10240: (512, 7)
# Epochs:  0 Loss:  3.0974466800689697
# Processing batch from row 10240 to 10752: (512, 7)
# Epochs:  0 Loss:  3.169536590576172
# Processing batch from row 10752 to 11264: (512, 7)
# Epochs:  0 Loss:  3.096095323562622
# Processing batch from row 11264 to 11776: (512, 7)
# Epochs:  0 Loss:  2.973379373550415
# Processing batch from row 11776 to 12288: (512, 7)
# Epochs:  0 Loss:  3.0127174854278564
# Processing batch from row 12288 to 12800: (512, 7)
# Epochs:  0 Loss:  3.039269208908081
# Processing batch from row 12800 to 13312: (512, 7)
# Epochs:  0 Loss:  3.1972339153289795
# Processing batch from row 13312 to 13824: (512, 7)
# Epochs:  0 Loss:  3.014559745788574
# Processing batch from row 13824 to 14336: (512, 7)
# Epochs:  0 Loss:  3.0076329708099365
# Processing batch from row 14336 to 14848: (512, 7)
# Epochs:  0 Loss:  2.9569575786590576
# Processing batch from row 14848 to 15360: (512, 7)
# Epochs:  0 Loss:  2.9818077087402344
# Processing batch from row 15360 to 15872: (512, 7)
# Epochs:  0 Loss:  2.9690046310424805
# Processing batch from row 15872 to 16384: (512, 7)
# Epochs:  0 Loss:  2.958923578262329
# Processing batch from row 16384 to 16896: (512, 7)
# Epochs:  0 Loss:  3.0082921981811523
# Processing batch from row 16896 to 17408: (512, 7)
# Epochs:  0 Loss:  3.2798783779144287
# Processing batch from row 17408 to 17920: (512, 7)
# Epochs:  0 Loss:  3.1867494583129883
# Processing batch from row 17920 to 18432: (512, 7)
# Epochs:  0 Loss:  3.1232736110687256
# Processing batch from row 18432 to 18944: (512, 7)
# Epochs:  0 Loss:  3.0496437549591064
# Processing batch from row 18944 to 19456: (512, 7)
# Epochs:  0 Loss:  3.03204345703125
# Processing batch from row 19456 to 19968: (512, 7)
# Epochs:  0 Loss:  3.0435149669647217
# Processing batch from row 19968 to 20480: (512, 7)
# Epochs:  0 Loss:  3.0250155925750732
# Processing batch from row 20480 to 20992: (512, 7)
# Epochs:  0 Loss:  3.0196025371551514
# Processing batch from row 20992 to 21504: (512, 7)
# Epochs:  0 Loss:  3.0288820266723633
# Processing batch from row 21504 to 22016: (512, 7)
# Epochs:  0 Loss:  3.2254974842071533
# Processing batch from row 22016 to 22528: (512, 7)
# Epochs:  0 Loss:  3.1519546508789062
# Processing batch from row 22528 to 23040: (512, 7)
# Epochs:  0 Loss:  3.039361000061035
# Processing batch from row 23040 to 23552: (512, 7)
# Epochs:  0 Loss:  2.990802049636841
# Processing batch from row 23552 to 24064: (512, 7)
# Epochs:  0 Loss:  3.032689332962036
# Processing batch from row 24064 to 24576: (512, 7)
# Epochs:  0 Loss:  2.993497133255005
# Processing batch from row 24576 to 25088: (512, 7)
# Epochs:  0 Loss:  3.029484510421753
# Processing batch from row 25088 to 25600: (512, 7)
# Epochs:  0 Loss:  3.0569143295288086
# Processing batch from row 25600 to 26112: (512, 7)
# Epochs:  0 Loss:  3.0491628646850586
# Processing batch from row 26112 to 26624: (512, 7)
# Epochs:  0 Loss:  3.074305534362793
# Processing batch from row 26624 to 27136: (512, 7)
# Epochs:  0 Loss:  3.12441086769104
# Processing batch from row 27136 to 27648: (512, 7)
# Epochs:  0 Loss:  3.0964105129241943
# Processing batch from row 27648 to 28160: (512, 7)
# Epochs:  0 Loss:  3.0881268978118896
# Processing batch from row 28160 to 28672: (512, 7)
# Epochs:  0 Loss:  3.1741578578948975
# Processing batch from row 28672 to 29184: (512, 7)
# Epochs:  0 Loss:  3.249098539352417
# Processing batch from row 29184 to 29696: (512, 7)
# Epochs:  0 Loss:  3.0633983612060547
# Processing batch from row 29696 to 30208: (512, 7)
# Epochs:  0 Loss:  3.0019474029541016
# Processing batch from row 30208 to 30720: (512, 7)
# Epochs:  0 Loss:  3.2103281021118164
# Processing batch from row 30720 to 31232: (512, 7)
# Epochs:  0 Loss:  3.211005210876465
# Processing batch from row 31232 to 31744: (512, 7)
# Epochs:  0 Loss:  3.0609261989593506
# Processing batch from row 31744 to 32256: (512, 7)
# Epochs:  0 Loss:  3.036449670791626
# Processing batch from row 32256 to 32768: (512, 7)
# Epochs:  0 Loss:  3.0518410205841064
# Processing batch from row 32768 to 33280: (512, 7)
# Epochs:  0 Loss:  3.1385257244110107
# Processing batch from row 33280 to 33792: (512, 7)
# Epochs:  0 Loss:  3.0182180404663086
# Processing batch from row 33792 to 34304: (512, 7)
# Epochs:  0 Loss:  3.026559591293335
# Processing batch from row 34304 to 34816: (512, 7)
# Epochs:  0 Loss:  3.0470468997955322
# Processing batch from row 34816 to 35328: (512, 7)
# Epochs:  0 Loss:  3.086270332336426
# Processing batch from row 35328 to 35840: (512, 7)
# Epochs:  0 Loss:  3.0466830730438232
# Processing batch from row 35840 to 36352: (512, 7)
# Epochs:  0 Loss:  2.9758269786834717
# Processing batch from row 36352 to 36864: (512, 7)
# Epochs:  0 Loss:  2.9368858337402344
# Processing batch from row 36864 to 37376: (512, 7)
# Epochs:  0 Loss:  2.938739776611328
# Processing batch from row 37376 to 37888: (512, 7)
# Epochs:  0 Loss:  2.9508485794067383
# Processing batch from row 37888 to 38400: (512, 7)
# Epochs:  0 Loss:  2.9495420455932617
# Processing batch from row 38400 to 38912: (512, 7)
# Epochs:  0 Loss:  2.9967572689056396
# Processing batch from row 38912 to 39424: (512, 7)
# Epochs:  0 Loss:  2.9920482635498047
# Processing batch from row 39424 to 39936: (512, 7)
# Epochs:  0 Loss:  3.0032689571380615
# Processing batch from row 39936 to 40448: (512, 7)
# Epochs:  0 Loss:  2.996148109436035
# Processing batch from row 40448 to 40960: (512, 7)
# Epochs:  0 Loss:  3.027379035949707
# Processing batch from row 40960 to 41472: (512, 7)
# Epochs:  0 Loss:  3.074876070022583
# Processing batch from row 41472 to 41984: (512, 7)
# Epochs:  0 Loss:  3.068361520767212
# Processing batch from row 41984 to 42496: (512, 7)
# Epochs:  0 Loss:  3.1154870986938477
# Processing batch from row 42496 to 43008: (512, 7)
# Epochs:  0 Loss:  3.1809871196746826
# Processing batch from row 43008 to 43520: (512, 7)
# Epochs:  0 Loss:  3.041471242904663
# Processing batch from row 43520 to 44032: (512, 7)
# Epochs:  0 Loss:  3.026829957962036
# Processing batch from row 44032 to 44544: (512, 7)
# Epochs:  0 Loss:  3.05745530128479
# Processing batch from row 44544 to 45056: (512, 7)
# Epochs:  0 Loss:  3.024049997329712
# Processing batch from row 45056 to 45568: (512, 7)
# Epochs:  0 Loss:  2.95683217048645
# Processing batch from row 45568 to 46080: (512, 7)
# Epochs:  0 Loss:  3.0658645629882812
# Processing batch from row 46080 to 46592: (512, 7)
# Epochs:  0 Loss:  2.9925644397735596
# Processing batch from row 46592 to 47104: (512, 7)
# Epochs:  0 Loss:  2.9721944332122803
# Processing batch from row 47104 to 47616: (512, 7)
# Epochs:  0 Loss:  2.953864336013794
# Processing batch from row 47616 to 48128: (512, 7)
# Epochs:  0 Loss:  2.9623844623565674
# Processing batch from row 48128 to 48640: (512, 7)
# Epochs:  0 Loss:  2.9896771907806396
# Processing batch from row 48640 to 49152: (512, 7)
# Epochs:  0 Loss:  3.024592399597168
# Processing batch from row 49152 to 49664: (512, 7)
# Epochs:  0 Loss:  3.0451819896698
# Processing batch from row 49664 to 50176: (512, 7)
# Epochs:  0 Loss:  3.003129720687866
# Processing batch from row 50176 to 50688: (512, 7)
# Epochs:  0 Loss:  3.039250373840332
# Processing batch from row 50688 to 51200: (512, 7)
# Epochs:  0 Loss:  2.9696044921875
# Processing batch from row 51200 to 51712: (512, 7)
# Epochs:  0 Loss:  2.997025728225708
# Processing batch from row 51712 to 52224: (512, 7)
# Epochs:  0 Loss:  2.9437782764434814
# Processing batch from row 52224 to 52736: (512, 7)
# Epochs:  0 Loss:  2.9846885204315186
# Processing batch from row 52736 to 53248: (512, 7)
# Epochs:  0 Loss:  3.045607805252075
# Processing batch from row 53248 to 53760: (512, 7)
# Epochs:  0 Loss:  3.012800455093384
# Processing batch from row 53760 to 54272: (512, 7)
# Epochs:  0 Loss:  3.0774123668670654
# Processing batch from row 54272 to 54784: (512, 7)
# Epochs:  0 Loss:  3.0774824619293213
# Processing batch from row 54784 to 55296: (512, 7)
# Epochs:  0 Loss:  3.067263603210449
# Processing batch from row 55296 to 55808: (512, 7)
# Epochs:  0 Loss:  2.997183084487915
# Processing batch from row 55808 to 56320: (512, 7)
# Epochs:  0 Loss:  3.0878400802612305
# Processing batch from row 56320 to 56832: (512, 7)
# Epochs:  0 Loss:  3.074699640274048
# Processing batch from row 56832 to 57344: (512, 7)
# Epochs:  0 Loss:  3.052793502807617
# Processing batch from row 57344 to 57856: (512, 7)
# Epochs:  0 Loss:  2.979656934738159
# Processing batch from row 57856 to 58368: (512, 7)
# Epochs:  0 Loss:  2.966506242752075
# Processing batch from row 58368 to 58880: (512, 7)
# Epochs:  0 Loss:  2.9832820892333984
# Processing batch from row 58880 to 59392: (512, 7)
# Epochs:  0 Loss:  2.963888168334961
# Processing batch from row 59392 to 59904: (512, 7)
# Epochs:  0 Loss:  2.975376844406128
# Processing batch from row 59904 to 60416: (512, 7)
# Epochs:  0 Loss:  2.9393513202667236
# Processing batch from row 60416 to 60928: (512, 7)
# Epochs:  0 Loss:  2.9071242809295654
# Processing batch from row 60928 to 61440: (512, 7)
# Epochs:  0 Loss:  2.889608144760132
# Processing batch from row 61440 to 61952: (512, 7)
# Epochs:  0 Loss:  2.9006357192993164
# Processing batch from row 61952 to 62464: (512, 7)
# Epochs:  0 Loss:  2.95987868309021
# Processing batch from row 62464 to 62976: (512, 7)
# Epochs:  0 Loss:  2.995345115661621
# Processing batch from row 62976 to 63488: (512, 7)
# Epochs:  0 Loss:  3.0487067699432373
# Processing batch from row 63488 to 64000: (512, 7)
# Epochs:  0 Loss:  3.048457145690918
# Processing batch from row 64000 to 64512: (512, 7)
# Epochs:  0 Loss:  3.0335280895233154
# Processing batch from row 64512 to 65024: (512, 7)
# Epochs:  0 Loss:  3.083101987838745
# Processing batch from row 65024 to 65536: (512, 7)
# Epochs:  0 Loss:  3.04256272315979
# Processing batch from row 65536 to 66048: (512, 7)
# Epochs:  0 Loss:  3.04302978515625
# Processing batch from row 66048 to 66560: (512, 7)
# Epochs:  0 Loss:  3.0504703521728516
# Processing batch from row 66560 to 67072: (512, 7)
# Epochs:  0 Loss:  2.9800517559051514
# Processing batch from row 67072 to 67584: (512, 7)
# Epochs:  0 Loss:  2.997373342514038
# Processing batch from row 67584 to 68096: (512, 7)
# Epochs:  0 Loss:  2.963935136795044
# Processing batch from row 68096 to 68608: (512, 7)
# Epochs:  0 Loss:  2.8463895320892334
# Processing batch from row 68608 to 69120: (512, 7)
# Epochs:  0 Loss:  2.8771679401397705
# Processing batch from row 69120 to 69632: (512, 7)
# Epochs:  0 Loss:  2.9314517974853516
# Processing batch from row 69632 to 70144: (512, 7)
# Epochs:  0 Loss:  2.8965375423431396
# Processing batch from row 70144 to 70656: (512, 7)
# Epochs:  0 Loss:  2.975266218185425
# Processing batch from row 70656 to 71168: (512, 7)
# Epochs:  0 Loss:  2.9863245487213135
# Processing batch from row 71168 to 71680: (512, 7)
# Epochs:  0 Loss:  3.1437692642211914
# Processing batch from row 71680 to 72192: (512, 7)
# Epochs:  0 Loss:  3.0979697704315186
# Processing batch from row 72192 to 72704: (512, 7)
# Epochs:  0 Loss:  2.9044406414031982
# Processing batch from row 72704 to 73216: (512, 7)
# Epochs:  0 Loss:  3.111382484436035
# Processing batch from row 73216 to 73728: (512, 7)
# Epochs:  0 Loss:  3.0820960998535156
# Processing batch from row 73728 to 74240: (512, 7)
# Epochs:  0 Loss:  3.0565950870513916
# Processing batch from row 74240 to 74752: (512, 7)
# Epochs:  0 Loss:  3.1777305603027344
# Processing batch from row 74752 to 75264: (512, 7)
# Epochs:  0 Loss:  3.296947717666626
# Processing batch from row 75264 to 75776: (512, 7)
# Epochs:  0 Loss:  3.068958044052124
# Processing batch from row 75776 to 76288: (512, 7)
# Epochs:  0 Loss:  2.8818986415863037
# Processing batch from row 76288 to 76800: (512, 7)
# Epochs:  0 Loss:  2.905984878540039
# Processing batch from row 76800 to 77312: (512, 7)
# Epochs:  0 Loss:  3.152120590209961
# Processing batch from row 77312 to 77824: (512, 7)
# Epochs:  0 Loss:  3.0701372623443604
# Processing batch from row 77824 to 78336: (512, 7)
# Epochs:  0 Loss:  3.1964550018310547
# Processing batch from row 78336 to 78848: (512, 7)
# Epochs:  0 Loss:  3.0499541759490967
# Processing batch from row 78848 to 79360: (512, 7)
# Epochs:  0 Loss:  3.118656873703003
# Processing batch from row 79360 to 79872: (512, 7)
# Epochs:  0 Loss:  3.0687825679779053
# Processing batch from row 79872 to 80384: (512, 7)
# Epochs:  0 Loss:  3.0677144527435303
# Processing batch from row 80384 to 80896: (512, 7)
# Epochs:  0 Loss:  3.0716006755828857
# Processing batch from row 80896 to 81408: (512, 7)
# Epochs:  0 Loss:  3.061480760574341
# Processing batch from row 81408 to 81920: (512, 7)
# Epochs:  0 Loss:  3.106952428817749
# Processing batch from row 81920 to 82432: (512, 7)
# Epochs:  0 Loss:  3.1375513076782227
# Processing batch from row 82432 to 82944: (512, 7)
# Epochs:  0 Loss:  3.055145025253296
# Processing batch from row 82944 to 83456: (512, 7)
# Epochs:  0 Loss:  3.0587127208709717
# Processing batch from row 83456 to 83968: (512, 7)
# Epochs:  0 Loss:  3.004359006881714
# Processing batch from row 83968 to 84480: (512, 7)
# Epochs:  0 Loss:  3.0408575534820557
# Processing batch from row 84480 to 84992: (512, 7)
# Epochs:  0 Loss:  2.990940809249878
# Processing batch from row 84992 to 85504: (512, 7)
# Epochs:  0 Loss:  2.9885427951812744
# Processing batch from row 85504 to 86016: (512, 7)
# Epochs:  0 Loss:  2.993854284286499
# Processing batch from row 86016 to 86528: (512, 7)
# Epochs:  0 Loss:  3.0128116607666016
# Processing batch from row 86528 to 87040: (512, 7)
# Epochs:  0 Loss:  3.0322790145874023
# Processing batch from row 87040 to 87552: (512, 7)
# Epochs:  0 Loss:  3.056089162826538
# Processing batch from row 87552 to 88064: (512, 7)
# Epochs:  0 Loss:  3.0498697757720947
# Processing batch from row 88064 to 88576: (512, 7)
# Epochs:  0 Loss:  3.013246774673462
# Processing batch from row 88576 to 89088: (512, 7)
# Epochs:  0 Loss:  2.9941461086273193
# Processing batch from row 89088 to 89600: (512, 7)
# Epochs:  0 Loss:  3.011756181716919
# Processing batch from row 89600 to 90112: (512, 7)
# Epochs:  0 Loss:  3.0043210983276367
# Processing batch from row 90112 to 90624: (512, 7)
# Epochs:  0 Loss:  2.985736131668091
# Processing batch from row 90624 to 91136: (512, 7)
# Epochs:  0 Loss:  2.974771738052368
# Processing batch from row 91136 to 91648: (512, 7)
# Epochs:  0 Loss:  2.9915144443511963
# Processing batch from row 91648 to 92160: (512, 7)
# Epochs:  0 Loss:  2.9631621837615967
# Processing batch from row 92160 to 92672: (512, 7)
# Epochs:  0 Loss:  2.976393938064575
# Processing batch from row 92672 to 93184: (512, 7)
# Epochs:  0 Loss:  2.958571195602417
# Processing batch from row 93184 to 93696: (512, 7)
# Epochs:  0 Loss:  2.965505838394165
# Processing batch from row 93696 to 94208: (512, 7)
# Epochs:  0 Loss:  2.9684646129608154
# Processing batch from row 94208 to 94720: (512, 7)
# Epochs:  0 Loss:  2.947617530822754
# Processing batch from row 94720 to 95232: (512, 7)
# Epochs:  0 Loss:  2.941335916519165
# Processing batch from row 95232 to 95744: (512, 7)
# Epochs:  0 Loss:  2.975379228591919
# Processing batch from row 95744 to 96256: (512, 7)
# Epochs:  0 Loss:  2.95092511177063
# Processing batch from row 96256 to 96768: (512, 7)
# Epochs:  0 Loss:  2.92744517326355
# Processing batch from row 96768 to 97053: (285, 7)
# Epochs:  0 Loss:  2.9062981605529785
# loss mean:  3.051441703344646
# ['Annual_premium', 'Area', 'Policy_start_date', 'Vehicle_year', 'Claim_amount', 'Age', 'Vehicle_risk_type']
# Processing batch from row 0 to 512: (512, 7)
# Epochs:  1 Loss:  3.0965871810913086
# Processing batch from row 512 to 1024: (512, 7)
# Epochs:  1 Loss:  3.378466844558716
# Processing batch from row 1024 to 1536: (512, 7)
# Epochs:  1 Loss:  3.134290933609009
# Processing batch from row 1536 to 2048: (512, 7)
# Epochs:  1 Loss:  3.090643882751465
# Processing batch from row 2048 to 2560: (512, 7)
# Epochs:  1 Loss:  3.05239200592041
# Processing batch from row 2560 to 3072: (512, 7)
# Epochs:  1 Loss:  3.042053461074829
# Processing batch from row 3072 to 3584: (512, 7)
# Epochs:  1 Loss:  3.2844784259796143
# Processing batch from row 3584 to 4096: (512, 7)
# Epochs:  1 Loss:  3.1015398502349854
# Processing batch from row 4096 to 4608: (512, 7)
# Epochs:  1 Loss:  3.0242607593536377
# Processing batch from row 4608 to 5120: (512, 7)
# Epochs:  1 Loss:  3.034515619277954
# Processing batch from row 5120 to 5632: (512, 7)
# Epochs:  1 Loss:  3.131911277770996
# Processing batch from row 5632 to 6144: (512, 7)
# Epochs:  1 Loss:  3.0971691608428955
# Processing batch from row 6144 to 6656: (512, 7)
# Epochs:  1 Loss:  3.183831214904785
# Processing batch from row 6656 to 7168: (512, 7)
# Epochs:  1 Loss:  3.007143259048462
# Processing batch from row 7168 to 7680: (512, 7)
# Epochs:  1 Loss:  2.99257755279541
# Processing batch from row 7680 to 8192: (512, 7)
# Epochs:  1 Loss:  2.9545791149139404
# Processing batch from row 8192 to 8704: (512, 7)
# Epochs:  1 Loss:  2.9878156185150146
# Processing batch from row 8704 to 9216: (512, 7)
# Epochs:  1 Loss:  2.9917585849761963
# Processing batch from row 9216 to 9728: (512, 7)
# Epochs:  1 Loss:  3.039255142211914
# Processing batch from row 9728 to 10240: (512, 7)
# Epochs:  1 Loss:  3.066598653793335
# Processing batch from row 10240 to 10752: (512, 7)
# Epochs:  1 Loss:  3.1540327072143555
# Processing batch from row 10752 to 11264: (512, 7)
# Epochs:  1 Loss:  3.066404104232788
# Processing batch from row 11264 to 11776: (512, 7)
# Epochs:  1 Loss:  2.9452056884765625
# Processing batch from row 11776 to 12288: (512, 7)
# Epochs:  1 Loss:  2.98815655708313
# Processing batch from row 12288 to 12800: (512, 7)
# Epochs:  1 Loss:  3.0138185024261475
# Processing batch from row 12800 to 13312: (512, 7)
# Epochs:  1 Loss:  3.170194387435913
# Processing batch from row 13312 to 13824: (512, 7)
# Epochs:  1 Loss:  2.997089385986328
# Processing batch from row 13824 to 14336: (512, 7)
# Epochs:  1 Loss:  2.992429733276367
# Processing batch from row 14336 to 14848: (512, 7)
# Epochs:  1 Loss:  2.9473276138305664
# Processing batch from row 14848 to 15360: (512, 7)
# Epochs:  1 Loss:  2.9708502292633057
# Processing batch from row 15360 to 15872: (512, 7)
# Epochs:  1 Loss:  2.9621963500976562
# Processing batch from row 15872 to 16384: (512, 7)
# Epochs:  1 Loss:  2.95827317237854
# Processing batch from row 16384 to 16896: (512, 7)
# Epochs:  1 Loss:  2.9922077655792236
# Processing batch from row 16896 to 17408: (512, 7)
# Epochs:  1 Loss:  3.2437095642089844
# Processing batch from row 17408 to 17920: (512, 7)
# Epochs:  1 Loss:  3.1550347805023193
# Processing batch from row 17920 to 18432: (512, 7)
# Epochs:  1 Loss:  3.0900533199310303
# Processing batch from row 18432 to 18944: (512, 7)
# Epochs:  1 Loss:  3.0324697494506836
# Processing batch from row 18944 to 19456: (512, 7)
# Epochs:  1 Loss:  3.0208394527435303
# Processing batch from row 19456 to 19968: (512, 7)
# Epochs:  1 Loss:  3.036574602127075
# Processing batch from row 19968 to 20480: (512, 7)
# Epochs:  1 Loss:  3.024705648422241
# Processing batch from row 20480 to 20992: (512, 7)
# Epochs:  1 Loss:  3.0102641582489014
# Processing batch from row 20992 to 21504: (512, 7)
# Epochs:  1 Loss:  3.034280776977539
# Processing batch from row 21504 to 22016: (512, 7)
# Epochs:  1 Loss:  3.2300498485565186
# Processing batch from row 22016 to 22528: (512, 7)
# Epochs:  1 Loss:  3.1775076389312744
# Processing batch from row 22528 to 23040: (512, 7)
# Epochs:  1 Loss:  3.0604333877563477
# Processing batch from row 23040 to 23552: (512, 7)
# Epochs:  1 Loss:  3.026198387145996
# Processing batch from row 23552 to 24064: (512, 7)
# Epochs:  1 Loss:  3.048828363418579
# Processing batch from row 24064 to 24576: (512, 7)
# Epochs:  1 Loss:  3.0005578994750977
# Processing batch from row 24576 to 25088: (512, 7)
# Epochs:  1 Loss:  3.020109176635742
# Processing batch from row 25088 to 25600: (512, 7)
# Epochs:  1 Loss:  3.044105291366577
# Processing batch from row 25600 to 26112: (512, 7)
# Epochs:  1 Loss:  3.021939516067505
# Processing batch from row 26112 to 26624: (512, 7)
# Epochs:  1 Loss:  3.041339635848999
# Processing batch from row 26624 to 27136: (512, 7)
# Epochs:  1 Loss:  3.0821731090545654
# Processing batch from row 27136 to 27648: (512, 7)
# Epochs:  1 Loss:  3.0684854984283447
# Processing batch from row 27648 to 28160: (512, 7)
# Epochs:  1 Loss:  3.074819326400757
# Processing batch from row 28160 to 28672: (512, 7)
# Epochs:  1 Loss:  3.1710145473480225
# Processing batch from row 28672 to 29184: (512, 7)
# Epochs:  1 Loss:  3.2337608337402344
# Processing batch from row 29184 to 29696: (512, 7)
# Epochs:  1 Loss:  3.044353485107422
# Processing batch from row 29696 to 30208: (512, 7)
# Epochs:  1 Loss:  2.9901812076568604
# Processing batch from row 30208 to 30720: (512, 7)
# Epochs:  1 Loss:  3.217653512954712
# Processing batch from row 30720 to 31232: (512, 7)
# Epochs:  1 Loss:  3.23523211479187
# Processing batch from row 31232 to 31744: (512, 7)
# Epochs:  1 Loss:  3.0790774822235107
# Processing batch from row 31744 to 32256: (512, 7)
# Epochs:  1 Loss:  3.058919668197632
# Processing batch from row 32256 to 32768: (512, 7)
# Epochs:  1 Loss:  3.091829538345337
# Processing batch from row 32768 to 33280: (512, 7)
# Epochs:  1 Loss:  3.1709089279174805
# Processing batch from row 33280 to 33792: (512, 7)
# Epochs:  1 Loss:  3.0306236743927
# Processing batch from row 33792 to 34304: (512, 7)
# Epochs:  1 Loss:  3.0122196674346924
# Processing batch from row 34304 to 34816: (512, 7)
# Epochs:  1 Loss:  3.0257463455200195
# Processing batch from row 34816 to 35328: (512, 7)
# Epochs:  1 Loss:  3.1008942127227783
# Processing batch from row 35328 to 35840: (512, 7)
# Epochs:  1 Loss:  3.066706418991089
# Processing batch from row 35840 to 36352: (512, 7)
# Epochs:  1 Loss:  2.99716854095459
# Processing batch from row 36352 to 36864: (512, 7)
# Epochs:  1 Loss:  2.953936815261841
# Processing batch from row 36864 to 37376: (512, 7)
# Epochs:  1 Loss:  2.9498558044433594
# Processing batch from row 37376 to 37888: (512, 7)
# Epochs:  1 Loss:  2.953457832336426
# Processing batch from row 37888 to 38400: (512, 7)
# Epochs:  1 Loss:  2.949733018875122
# Processing batch from row 38400 to 38912: (512, 7)
# Epochs:  1 Loss:  2.998947858810425
# Processing batch from row 38912 to 39424: (512, 7)
# Epochs:  1 Loss:  2.992133378982544
# Processing batch from row 39424 to 39936: (512, 7)
# Epochs:  1 Loss:  2.9972503185272217
# Processing batch from row 39936 to 40448: (512, 7)
# Epochs:  1 Loss:  2.987637758255005
# Processing batch from row 40448 to 40960: (512, 7)
# Epochs:  1 Loss:  3.018350839614868
# Processing batch from row 40960 to 41472: (512, 7)
# Epochs:  1 Loss:  3.063593864440918
# Processing batch from row 41472 to 41984: (512, 7)
# Epochs:  1 Loss:  3.0569283962249756
# Processing batch from row 41984 to 42496: (512, 7)
# Epochs:  1 Loss:  3.1137197017669678
# Processing batch from row 42496 to 43008: (512, 7)
# Epochs:  1 Loss:  3.1831066608428955
# Processing batch from row 43008 to 43520: (512, 7)
# Epochs:  1 Loss:  3.0475876331329346
# Processing batch from row 43520 to 44032: (512, 7)
# Epochs:  1 Loss:  3.024442672729492
# Processing batch from row 44032 to 44544: (512, 7)
# Epochs:  1 Loss:  3.061934471130371
# Processing batch from row 44544 to 45056: (512, 7)
# Epochs:  1 Loss:  3.0283641815185547
# Processing batch from row 45056 to 45568: (512, 7)
# Epochs:  1 Loss:  2.948500394821167
# Processing batch from row 45568 to 46080: (512, 7)
# Epochs:  1 Loss:  3.0836451053619385
# Processing batch from row 46080 to 46592: (512, 7)
# Epochs:  1 Loss:  2.9994962215423584
# Processing batch from row 46592 to 47104: (512, 7)
# Epochs:  1 Loss:  2.97847843170166
# Processing batch from row 47104 to 47616: (512, 7)
# Epochs:  1 Loss:  2.938325881958008
# Processing batch from row 47616 to 48128: (512, 7)
# Epochs:  1 Loss:  2.9528377056121826
# Processing batch from row 48128 to 48640: (512, 7)
# Epochs:  1 Loss:  2.9860246181488037
# Processing batch from row 48640 to 49152: (512, 7)
# Epochs:  1 Loss:  3.0234830379486084
# Processing batch from row 49152 to 49664: (512, 7)
# Epochs:  1 Loss:  3.04376482963562
# Processing batch from row 49664 to 50176: (512, 7)
# Epochs:  1 Loss:  3.017831802368164
# Processing batch from row 50176 to 50688: (512, 7)
# Epochs:  1 Loss:  3.0422232151031494
# Processing batch from row 50688 to 51200: (512, 7)
# Epochs:  1 Loss:  2.9833898544311523
# Processing batch from row 51200 to 51712: (512, 7)
# Epochs:  1 Loss:  3.0190744400024414
# Processing batch from row 51712 to 52224: (512, 7)
# Epochs:  1 Loss:  2.9394922256469727
# Processing batch from row 52224 to 52736: (512, 7)
# Epochs:  1 Loss:  2.977407217025757
# Processing batch from row 52736 to 53248: (512, 7)
# Epochs:  1 Loss:  3.0298728942871094
# Processing batch from row 53248 to 53760: (512, 7)
# Epochs:  1 Loss:  3.014030694961548
# Processing batch from row 53760 to 54272: (512, 7)
# Epochs:  1 Loss:  3.073369026184082
# Processing batch from row 54272 to 54784: (512, 7)
# Epochs:  1 Loss:  3.072462797164917
# Processing batch from row 54784 to 55296: (512, 7)
# Epochs:  1 Loss:  3.064988136291504
# Processing batch from row 55296 to 55808: (512, 7)
# Epochs:  1 Loss:  2.9994287490844727
# Processing batch from row 55808 to 56320: (512, 7)
# Epochs:  1 Loss:  3.088385820388794
# Processing batch from row 56320 to 56832: (512, 7)
# Epochs:  1 Loss:  3.0741565227508545
# Processing batch from row 56832 to 57344: (512, 7)
# Epochs:  1 Loss:  3.0566654205322266
# Processing batch from row 57344 to 57856: (512, 7)
# Epochs:  1 Loss:  2.997544288635254
# Processing batch from row 57856 to 58368: (512, 7)
# Epochs:  1 Loss:  2.97579288482666
# Processing batch from row 58368 to 58880: (512, 7)
# Epochs:  1 Loss:  2.9975602626800537
# Processing batch from row 58880 to 59392: (512, 7)
# Epochs:  1 Loss:  2.969446897506714
# Processing batch from row 59392 to 59904: (512, 7)
# Epochs:  1 Loss:  2.968454599380493
# Processing batch from row 59904 to 60416: (512, 7)
# Epochs:  1 Loss:  2.945737600326538
# Processing batch from row 60416 to 60928: (512, 7)
# Epochs:  1 Loss:  2.9203999042510986
# Processing batch from row 60928 to 61440: (512, 7)
# Epochs:  1 Loss:  2.9002935886383057
# Processing batch from row 61440 to 61952: (512, 7)
# Epochs:  1 Loss:  2.9112842082977295
# Processing batch from row 61952 to 62464: (512, 7)
# Epochs:  1 Loss:  2.966430902481079
# Processing batch from row 62464 to 62976: (512, 7)
# Epochs:  1 Loss:  3.006537675857544
# Processing batch from row 62976 to 63488: (512, 7)
# Epochs:  1 Loss:  3.051190137863159
# Processing batch from row 63488 to 64000: (512, 7)
# Epochs:  1 Loss:  3.0297229290008545
# Processing batch from row 64000 to 64512: (512, 7)
# Epochs:  1 Loss:  3.0185811519622803
# Processing batch from row 64512 to 65024: (512, 7)
# Epochs:  1 Loss:  3.0546977519989014
# Processing batch from row 65024 to 65536: (512, 7)
# Epochs:  1 Loss:  3.0143001079559326
# Processing batch from row 65536 to 66048: (512, 7)
# Epochs:  1 Loss:  3.016242027282715
# Processing batch from row 66048 to 66560: (512, 7)
# Epochs:  1 Loss:  3.0297281742095947
# Processing batch from row 66560 to 67072: (512, 7)
# Epochs:  1 Loss:  2.963038444519043
# Processing batch from row 67072 to 67584: (512, 7)
# Epochs:  1 Loss:  2.9836175441741943
# Processing batch from row 67584 to 68096: (512, 7)
# Epochs:  1 Loss:  2.956397771835327
# Processing batch from row 68096 to 68608: (512, 7)
# Epochs:  1 Loss:  2.844011068344116
# Processing batch from row 68608 to 69120: (512, 7)
# Epochs:  1 Loss:  2.877537727355957
# Processing batch from row 69120 to 69632: (512, 7)
# Epochs:  1 Loss:  2.93694806098938
# Processing batch from row 69632 to 70144: (512, 7)
# Epochs:  1 Loss:  2.902963638305664
# Processing batch from row 70144 to 70656: (512, 7)
# Epochs:  1 Loss:  2.9722988605499268
# Processing batch from row 70656 to 71168: (512, 7)
# Epochs:  1 Loss:  2.9801511764526367
# Processing batch from row 71168 to 71680: (512, 7)
# Epochs:  1 Loss:  3.1299960613250732
# Processing batch from row 71680 to 72192: (512, 7)
# Epochs:  1 Loss:  3.087754487991333
# Processing batch from row 72192 to 72704: (512, 7)
# Epochs:  1 Loss:  2.8983078002929688
# Processing batch from row 72704 to 73216: (512, 7)
# Epochs:  1 Loss:  3.103505849838257
# Processing batch from row 73216 to 73728: (512, 7)
# Epochs:  1 Loss:  3.06949782371521
# Processing batch from row 73728 to 74240: (512, 7)
# Epochs:  1 Loss:  3.041170120239258
# Processing batch from row 74240 to 74752: (512, 7)
# Epochs:  1 Loss:  3.1615493297576904
# Processing batch from row 74752 to 75264: (512, 7)
# Epochs:  1 Loss:  3.2787911891937256
# Processing batch from row 75264 to 75776: (512, 7)
# Epochs:  1 Loss:  3.058746099472046
# Processing batch from row 75776 to 76288: (512, 7)
# Epochs:  1 Loss:  2.875060796737671
# Processing batch from row 76288 to 76800: (512, 7)
# Epochs:  1 Loss:  2.8960182666778564
# Processing batch from row 76800 to 77312: (512, 7)
# Epochs:  1 Loss:  3.1401641368865967
# Processing batch from row 77312 to 77824: (512, 7)
# Epochs:  1 Loss:  3.074054718017578
# Processing batch from row 77824 to 78336: (512, 7)
# Epochs:  1 Loss:  3.179929733276367
# Processing batch from row 78336 to 78848: (512, 7)
# Epochs:  1 Loss:  3.0456416606903076
# Processing batch from row 78848 to 79360: (512, 7)
# Epochs:  1 Loss:  3.112727403640747
# Processing batch from row 79360 to 79872: (512, 7)
# Epochs:  1 Loss:  3.0683796405792236
# Processing batch from row 79872 to 80384: (512, 7)
# Epochs:  1 Loss:  3.0564613342285156
# Processing batch from row 80384 to 80896: (512, 7)
# Epochs:  1 Loss:  3.060274362564087
# Processing batch from row 80896 to 81408: (512, 7)
# Epochs:  1 Loss:  3.0516395568847656
# Processing batch from row 81408 to 81920: (512, 7)
# Epochs:  1 Loss:  3.0914571285247803
# Processing batch from row 81920 to 82432: (512, 7)
# Epochs:  1 Loss:  3.123654365539551
# Processing batch from row 82432 to 82944: (512, 7)
# Epochs:  1 Loss:  3.042085647583008
# Processing batch from row 82944 to 83456: (512, 7)
# Epochs:  1 Loss:  3.039978265762329
# Processing batch from row 83456 to 83968: (512, 7)
# Epochs:  1 Loss:  2.9778802394866943
# Processing batch from row 83968 to 84480: (512, 7)
# Epochs:  1 Loss:  3.013425827026367
# Processing batch from row 84480 to 84992: (512, 7)
# Epochs:  1 Loss:  2.953462600708008
# Processing batch from row 84992 to 85504: (512, 7)
# Epochs:  1 Loss:  2.947720766067505
# Processing batch from row 85504 to 86016: (512, 7)
# Epochs:  1 Loss:  2.9931180477142334
# Processing batch from row 86016 to 86528: (512, 7)
# Epochs:  1 Loss:  2.971759796142578
# Processing batch from row 86528 to 87040: (512, 7)
# Epochs:  1 Loss:  2.9872958660125732
# Processing batch from row 87040 to 87552: (512, 7)
# Epochs:  1 Loss:  3.014531373977661
# Processing batch from row 87552 to 88064: (512, 7)
# Epochs:  1 Loss:  3.008272409439087
# Processing batch from row 88064 to 88576: (512, 7)
# Epochs:  1 Loss:  2.9619061946868896
# Processing batch from row 88576 to 89088: (512, 7)
# Epochs:  1 Loss:  2.9337122440338135
# Processing batch from row 89088 to 89600: (512, 7)
# Epochs:  1 Loss:  2.9601259231567383
# Processing batch from row 89600 to 90112: (512, 7)
# Epochs:  1 Loss:  2.9433753490448
# Processing batch from row 90112 to 90624: (512, 7)
# Epochs:  1 Loss:  2.9118025302886963
# Processing batch from row 90624 to 91136: (512, 7)
# Epochs:  1 Loss:  2.9013774394989014
# Processing batch from row 91136 to 91648: (512, 7)
# Epochs:  1 Loss:  2.912843704223633
# Processing batch from row 91648 to 92160: (512, 7)
# Epochs:  1 Loss:  2.8916501998901367
# Processing batch from row 92160 to 92672: (512, 7)
# Epochs:  1 Loss:  2.9016125202178955
# Processing batch from row 92672 to 93184: (512, 7)
# Epochs:  1 Loss:  2.866122007369995
# Processing batch from row 93184 to 93696: (512, 7)
# Epochs:  1 Loss:  2.8799095153808594
# Processing batch from row 93696 to 94208: (512, 7)
# Epochs:  1 Loss:  2.8765172958374023
# Processing batch from row 94208 to 94720: (512, 7)
# Epochs:  1 Loss:  2.8578577041625977
# Processing batch from row 94720 to 95232: (512, 7)
# Epochs:  1 Loss:  2.853501558303833
# Processing batch from row 95232 to 95744: (512, 7)
# Epochs:  1 Loss:  2.884267807006836
# Processing batch from row 95744 to 96256: (512, 7)
# Epochs:  1 Loss:  2.851975202560425
# Processing batch from row 96256 to 96768: (512, 7)
# Epochs:  1 Loss:  2.8309242725372314
# Processing batch from row 96768 to 97053: (285, 7)
# Epochs:  1 Loss:  2.8093507289886475
# loss mean:  3.023595760997973
# ['Age', 'Vehicle_year', 'Area', 'Vehicle_risk_type', 'Annual_premium', 'Policy_start_date', 'Claim_amount']
# Processing batch from row 0 to 512: (512, 7)
# Epochs:  2 Loss:  3.733970880508423
# Processing batch from row 512 to 1024: (512, 7)
# Epochs:  2 Loss:  3.986215829849243
# Processing batch from row 1024 to 1536: (512, 7)
# Epochs:  2 Loss:  3.7226436138153076
# Processing batch from row 1536 to 2048: (512, 7)
# Epochs:  2 Loss:  3.5795724391937256
# Processing batch from row 2048 to 2560: (512, 7)
# Epochs:  2 Loss:  3.4042580127716064
# Processing batch from row 2560 to 3072: (512, 7)
# Epochs:  2 Loss:  3.2405548095703125
# Processing batch from row 3072 to 3584: (512, 7)
# Epochs:  2 Loss:  3.236414909362793
# Processing batch from row 3584 to 4096: (512, 7)
# Epochs:  2 Loss:  3.0597450733184814
# Processing batch from row 4096 to 4608: (512, 7)
# Epochs:  2 Loss:  3.179945230484009
# Processing batch from row 4608 to 5120: (512, 7)
# Epochs:  2 Loss:  3.186490297317505
# Processing batch from row 5120 to 5632: (512, 7)
# Epochs:  2 Loss:  3.1431875228881836
# Processing batch from row 5632 to 6144: (512, 7)
# Epochs:  2 Loss:  3.0832860469818115
# Processing batch from row 6144 to 6656: (512, 7)
# Epochs:  2 Loss:  3.060525894165039
# Processing batch from row 6656 to 7168: (512, 7)
# Epochs:  2 Loss:  3.015467882156372
# Processing batch from row 7168 to 7680: (512, 7)
# Epochs:  2 Loss:  3.0912883281707764
# Processing batch from row 7680 to 8192: (512, 7)
# Epochs:  2 Loss:  3.043001413345337
# Processing batch from row 8192 to 8704: (512, 7)
# Epochs:  2 Loss:  3.0177745819091797
# Processing batch from row 8704 to 9216: (512, 7)
# Epochs:  2 Loss:  2.9656388759613037
# Processing batch from row 9216 to 9728: (512, 7)
# Epochs:  2 Loss:  2.989501953125
# Processing batch from row 9728 to 10240: (512, 7)
# Epochs:  2 Loss:  2.992892265319824
# Processing batch from row 10240 to 10752: (512, 7)
# Epochs:  2 Loss:  3.025639533996582
# Processing batch from row 10752 to 11264: (512, 7)
# Epochs:  2 Loss:  3.0036697387695312
# Processing batch from row 11264 to 11776: (512, 7)
# Epochs:  2 Loss:  2.9007701873779297
# Processing batch from row 11776 to 12288: (512, 7)
# Epochs:  2 Loss:  2.929426431655884
# Processing batch from row 12288 to 12800: (512, 7)
# Epochs:  2 Loss:  2.9227466583251953
# Processing batch from row 12800 to 13312: (512, 7)
# Epochs:  2 Loss:  3.004746437072754
# Processing batch from row 13312 to 13824: (512, 7)
# Epochs:  2 Loss:  2.895914077758789
# Processing batch from row 13824 to 14336: (512, 7)
# Epochs:  2 Loss:  2.9378278255462646
# Processing batch from row 14336 to 14848: (512, 7)
# Epochs:  2 Loss:  2.9033267498016357
# Processing batch from row 14848 to 15360: (512, 7)
# Epochs:  2 Loss:  2.886578321456909
# Processing batch from row 15360 to 15872: (512, 7)
# Epochs:  2 Loss:  2.8596060276031494
# Processing batch from row 15872 to 16384: (512, 7)
# Epochs:  2 Loss:  2.8245556354522705
# Processing batch from row 16384 to 16896: (512, 7)
# Epochs:  2 Loss:  2.918002128601074
# Processing batch from row 16896 to 17408: (512, 7)
# Epochs:  2 Loss:  3.0831124782562256
# Processing batch from row 17408 to 17920: (512, 7)
# Epochs:  2 Loss:  3.0392513275146484
# Processing batch from row 17920 to 18432: (512, 7)
# Epochs:  2 Loss:  2.9783356189727783
# Processing batch from row 18432 to 18944: (512, 7)
# Epochs:  2 Loss:  2.973249673843384
# Processing batch from row 18944 to 19456: (512, 7)
# Epochs:  2 Loss:  2.9446699619293213
# Processing batch from row 19456 to 19968: (512, 7)
# Epochs:  2 Loss:  2.9876139163970947
# Processing batch from row 19968 to 20480: (512, 7)
# Epochs:  2 Loss:  2.9605062007904053
# Processing batch from row 20480 to 20992: (512, 7)
# Epochs:  2 Loss:  2.927842855453491
# Processing batch from row 20992 to 21504: (512, 7)
# Epochs:  2 Loss:  2.9176747798919678
# Processing batch from row 21504 to 22016: (512, 7)
# Epochs:  2 Loss:  3.0818164348602295
# Processing batch from row 22016 to 22528: (512, 7)
# Epochs:  2 Loss:  3.0627281665802
# Processing batch from row 22528 to 23040: (512, 7)
# Epochs:  2 Loss:  2.983426094055176
# Processing batch from row 23040 to 23552: (512, 7)
# Epochs:  2 Loss:  2.9476308822631836
# Processing batch from row 23552 to 24064: (512, 7)
# Epochs:  2 Loss:  3.0235559940338135
# Processing batch from row 24064 to 24576: (512, 7)
# Epochs:  2 Loss:  2.9445960521698
# Processing batch from row 24576 to 25088: (512, 7)
# Epochs:  2 Loss:  2.941476821899414
# Processing batch from row 25088 to 25600: (512, 7)
# Epochs:  2 Loss:  2.9081923961639404
# Processing batch from row 25600 to 26112: (512, 7)
# Epochs:  2 Loss:  2.903057098388672
# Processing batch from row 26112 to 26624: (512, 7)
# Epochs:  2 Loss:  2.8979833126068115
# Processing batch from row 26624 to 27136: (512, 7)
# Epochs:  2 Loss:  2.9492368698120117
# Processing batch from row 27136 to 27648: (512, 7)
# Epochs:  2 Loss:  2.9239461421966553
# Processing batch from row 27648 to 28160: (512, 7)
# Epochs:  2 Loss:  2.8969900608062744
# Processing batch from row 28160 to 28672: (512, 7)
# Epochs:  2 Loss:  3.0333120822906494
# Processing batch from row 28672 to 29184: (512, 7)
# Epochs:  2 Loss:  3.080716371536255
# Processing batch from row 29184 to 29696: (512, 7)
# Epochs:  2 Loss:  3.0290749073028564
# Processing batch from row 29696 to 30208: (512, 7)
# Epochs:  2 Loss:  2.969965696334839
# Processing batch from row 30208 to 30720: (512, 7)
# Epochs:  2 Loss:  3.0704174041748047
# Processing batch from row 30720 to 31232: (512, 7)
# Epochs:  2 Loss:  3.068908929824829
# Processing batch from row 31232 to 31744: (512, 7)
# Epochs:  2 Loss:  2.990602493286133
# Processing batch from row 31744 to 32256: (512, 7)
# Epochs:  2 Loss:  2.976163864135742
# Processing batch from row 32256 to 32768: (512, 7)
# Epochs:  2 Loss:  2.966674566268921
# Processing batch from row 32768 to 33280: (512, 7)
# Epochs:  2 Loss:  2.9412832260131836
# Processing batch from row 33280 to 33792: (512, 7)
# Epochs:  2 Loss:  2.8868234157562256
# Processing batch from row 33792 to 34304: (512, 7)
# Epochs:  2 Loss:  2.992762804031372
# Processing batch from row 34304 to 34816: (512, 7)
# Epochs:  2 Loss:  3.0256993770599365
# Processing batch from row 34816 to 35328: (512, 7)
# Epochs:  2 Loss:  2.9503209590911865
# Processing batch from row 35328 to 35840: (512, 7)
# Epochs:  2 Loss:  2.9048216342926025
# Processing batch from row 35840 to 36352: (512, 7)
# Epochs:  2 Loss:  2.8782670497894287
# Processing batch from row 36352 to 36864: (512, 7)
# Epochs:  2 Loss:  2.8873815536499023
# Processing batch from row 36864 to 37376: (512, 7)
# Epochs:  2 Loss:  2.9009618759155273
# Processing batch from row 37376 to 37888: (512, 7)
# Epochs:  2 Loss:  2.878441572189331
# Processing batch from row 37888 to 38400: (512, 7)
# Epochs:  2 Loss:  2.833531141281128
# Processing batch from row 38400 to 38912: (512, 7)
# Epochs:  2 Loss:  2.8423080444335938
# Processing batch from row 38912 to 39424: (512, 7)
# Epochs:  2 Loss:  2.7929484844207764
# Processing batch from row 39424 to 39936: (512, 7)
# Epochs:  2 Loss:  2.785776376724243
# Processing batch from row 39936 to 40448: (512, 7)
# Epochs:  2 Loss:  2.866039991378784
# Processing batch from row 40448 to 40960: (512, 7)
# Epochs:  2 Loss:  2.894453763961792
# Processing batch from row 40960 to 41472: (512, 7)
# Epochs:  2 Loss:  3.0215704441070557
# Processing batch from row 41472 to 41984: (512, 7)
# Epochs:  2 Loss:  3.0469653606414795
# Processing batch from row 41984 to 42496: (512, 7)
# Epochs:  2 Loss:  3.01985764503479
# Processing batch from row 42496 to 43008: (512, 7)
# Epochs:  2 Loss:  3.142221450805664
# Processing batch from row 43008 to 43520: (512, 7)
# Epochs:  2 Loss:  3.023644208908081
# Processing batch from row 43520 to 44032: (512, 7)
# Epochs:  2 Loss:  2.9641244411468506
# Processing batch from row 44032 to 44544: (512, 7)
# Epochs:  2 Loss:  3.0328867435455322
# Processing batch from row 44544 to 45056: (512, 7)
# Epochs:  2 Loss:  2.939580202102661
# Processing batch from row 45056 to 45568: (512, 7)
# Epochs:  2 Loss:  2.865126848220825
# Processing batch from row 45568 to 46080: (512, 7)
# Epochs:  2 Loss:  2.9289581775665283
# Processing batch from row 46080 to 46592: (512, 7)
# Epochs:  2 Loss:  2.991837501525879
# Processing batch from row 46592 to 47104: (512, 7)
# Epochs:  2 Loss:  2.8835232257843018
# Processing batch from row 47104 to 47616: (512, 7)
# Epochs:  2 Loss:  2.899582862854004
# Processing batch from row 47616 to 48128: (512, 7)
# Epochs:  2 Loss:  2.92374587059021
# Processing batch from row 48128 to 48640: (512, 7)
# Epochs:  2 Loss:  2.896289110183716
# Processing batch from row 48640 to 49152: (512, 7)
# Epochs:  2 Loss:  2.9841291904449463
# Processing batch from row 49152 to 49664: (512, 7)
# Epochs:  2 Loss:  2.9496467113494873
# Processing batch from row 49664 to 50176: (512, 7)
# Epochs:  2 Loss:  2.964045286178589
# Processing batch from row 50176 to 50688: (512, 7)
# Epochs:  2 Loss:  2.9505510330200195
# Processing batch from row 50688 to 51200: (512, 7)
# Epochs:  2 Loss:  2.934896230697632
# Processing batch from row 51200 to 51712: (512, 7)
# Epochs:  2 Loss:  2.9472532272338867
# Processing batch from row 51712 to 52224: (512, 7)
# Epochs:  2 Loss:  2.8855514526367188
# Processing batch from row 52224 to 52736: (512, 7)
# Epochs:  2 Loss:  2.932184934616089
# Processing batch from row 52736 to 53248: (512, 7)
# Epochs:  2 Loss:  2.9381625652313232
# Processing batch from row 53248 to 53760: (512, 7)
# Epochs:  2 Loss:  2.9319591522216797
# Processing batch from row 53760 to 54272: (512, 7)
# Epochs:  2 Loss:  2.9630956649780273
# Processing batch from row 54272 to 54784: (512, 7)
# Epochs:  2 Loss:  2.9117467403411865
# Processing batch from row 54784 to 55296: (512, 7)
# Epochs:  2 Loss:  2.9043266773223877
# Processing batch from row 55296 to 55808: (512, 7)
# Epochs:  2 Loss:  2.9330146312713623
# Processing batch from row 55808 to 56320: (512, 7)
# Epochs:  2 Loss:  2.871124267578125
# Processing batch from row 56320 to 56832: (512, 7)
# Epochs:  2 Loss:  2.9570882320404053
# Processing batch from row 56832 to 57344: (512, 7)
# Epochs:  2 Loss:  2.952681541442871
# Processing batch from row 57344 to 57856: (512, 7)
# Epochs:  2 Loss:  2.876880645751953
# Processing batch from row 57856 to 58368: (512, 7)
# Epochs:  2 Loss:  2.909515380859375
# Processing batch from row 58368 to 58880: (512, 7)
# Epochs:  2 Loss:  2.8790385723114014
# Processing batch from row 58880 to 59392: (512, 7)
# Epochs:  2 Loss:  2.892324447631836
# Processing batch from row 59392 to 59904: (512, 7)
# Epochs:  2 Loss:  2.9747438430786133
# Processing batch from row 59904 to 60416: (512, 7)
# Epochs:  2 Loss:  2.921919584274292
# Processing batch from row 60416 to 60928: (512, 7)
# Epochs:  2 Loss:  2.877370595932007
# Processing batch from row 60928 to 61440: (512, 7)
# Epochs:  2 Loss:  2.874429702758789
# Processing batch from row 61440 to 61952: (512, 7)
# Epochs:  2 Loss:  2.8925044536590576
# Processing batch from row 61952 to 62464: (512, 7)
# Epochs:  2 Loss:  2.9363667964935303
# Processing batch from row 62464 to 62976: (512, 7)
# Epochs:  2 Loss:  2.9433486461639404
# Processing batch from row 62976 to 63488: (512, 7)
# Epochs:  2 Loss:  3.0146615505218506
# Processing batch from row 63488 to 64000: (512, 7)
# Epochs:  2 Loss:  2.956857919692993
# Processing batch from row 64000 to 64512: (512, 7)
# Epochs:  2 Loss:  2.920848846435547
# Processing batch from row 64512 to 65024: (512, 7)
# Epochs:  2 Loss:  2.9554364681243896
# Processing batch from row 65024 to 65536: (512, 7)
# Epochs:  2 Loss:  2.962022066116333
# Processing batch from row 65536 to 66048: (512, 7)
# Epochs:  2 Loss:  2.937176465988159
# Processing batch from row 66048 to 66560: (512, 7)
# Epochs:  2 Loss:  2.9917335510253906
# Processing batch from row 66560 to 67072: (512, 7)
# Epochs:  2 Loss:  2.944709539413452
# Processing batch from row 67072 to 67584: (512, 7)
# Epochs:  2 Loss:  2.9762275218963623
# Processing batch from row 67584 to 68096: (512, 7)
# Epochs:  2 Loss:  2.954791307449341
# Processing batch from row 68096 to 68608: (512, 7)
# Epochs:  2 Loss:  2.8633015155792236
# Processing batch from row 68608 to 69120: (512, 7)
# Epochs:  2 Loss:  2.889009714126587
# Processing batch from row 69120 to 69632: (512, 7)
# Epochs:  2 Loss:  2.9574296474456787
# Processing batch from row 69632 to 70144: (512, 7)
# Epochs:  2 Loss:  2.8898918628692627
# Processing batch from row 70144 to 70656: (512, 7)
# Epochs:  2 Loss:  2.8839938640594482
# Processing batch from row 70656 to 71168: (512, 7)
# Epochs:  2 Loss:  2.8954737186431885
# Processing batch from row 71168 to 71680: (512, 7)
# Epochs:  2 Loss:  2.9553263187408447
# Processing batch from row 71680 to 72192: (512, 7)
# Epochs:  2 Loss:  3.012232542037964
# Processing batch from row 72192 to 72704: (512, 7)
# Epochs:  2 Loss:  2.8919990062713623
# Processing batch from row 72704 to 73216: (512, 7)
# Epochs:  2 Loss:  3.015063524246216
# Processing batch from row 73216 to 73728: (512, 7)
# Epochs:  2 Loss:  2.8593006134033203
# Processing batch from row 73728 to 74240: (512, 7)
# Epochs:  2 Loss:  2.8760693073272705
# Processing batch from row 74240 to 74752: (512, 7)
# Epochs:  2 Loss:  2.8687028884887695
# Processing batch from row 74752 to 75264: (512, 7)
# Epochs:  2 Loss:  2.983830451965332
# Processing batch from row 75264 to 75776: (512, 7)
# Epochs:  2 Loss:  2.9293575286865234
# Processing batch from row 75776 to 76288: (512, 7)
# Epochs:  2 Loss:  2.808593511581421
# Processing batch from row 76288 to 76800: (512, 7)
# Epochs:  2 Loss:  2.826899528503418
# Processing batch from row 76800 to 77312: (512, 7)
# Epochs:  2 Loss:  2.9669723510742188
# Processing batch from row 77312 to 77824: (512, 7)
# Epochs:  2 Loss:  2.9184114933013916
# Processing batch from row 77824 to 78336: (512, 7)
# Epochs:  2 Loss:  2.9983224868774414
# Processing batch from row 78336 to 78848: (512, 7)
# Epochs:  2 Loss:  2.9695281982421875
# Processing batch from row 78848 to 79360: (512, 7)
# Epochs:  2 Loss:  2.952772378921509
# Processing batch from row 79360 to 79872: (512, 7)
# Epochs:  2 Loss:  2.9869728088378906
# Processing batch from row 79872 to 80384: (512, 7)
# Epochs:  2 Loss:  3.0045576095581055
# Processing batch from row 80384 to 80896: (512, 7)
# Epochs:  2 Loss:  3.001610517501831
# Processing batch from row 80896 to 81408: (512, 7)
# Epochs:  2 Loss:  2.948906660079956
# Processing batch from row 81408 to 81920: (512, 7)
# Epochs:  2 Loss:  3.040315866470337
# Processing batch from row 81920 to 82432: (512, 7)
# Epochs:  2 Loss:  3.0567550659179688
# Processing batch from row 82432 to 82944: (512, 7)
# Epochs:  2 Loss:  2.973151206970215
# Processing batch from row 82944 to 83456: (512, 7)
# Epochs:  2 Loss:  2.998398542404175
# Processing batch from row 83456 to 83968: (512, 7)
# Epochs:  2 Loss:  2.9124202728271484
# Processing batch from row 83968 to 84480: (512, 7)
# Epochs:  2 Loss:  2.9175243377685547
# Processing batch from row 84480 to 84992: (512, 7)
# ...
# Epochs:  3 Loss:  3.164314031600952
# Processing batch from row 4096 to 4608: (512, 7)
# Epochs:  3 Loss:  3.088724136352539
# Processing batch from row 4608 to 5120: (512, 7)
# Epochs:  3 Loss:  3.0763490200042725
# Processing batch from row 5120 to 5632: (512, 7)
# Epochs:  3 Loss:  3.1440906524658203
# Processing batch from row 5632 to 6144: (512, 7)
# Epochs:  3 Loss:  3.1162946224212646
# Processing batch from row 6144 to 6656: (512, 7)
# Epochs:  3 Loss:  3.1899149417877197
# Processing batch from row 6656 to 7168: (512, 7)
# Epochs:  3 Loss:  3.0424606800079346
# Processing batch from row 7168 to 7680: (512, 7)
# Epochs:  3 Loss:  3.037447214126587
# Processing batch from row 7680 to 8192: (512, 7)
# Epochs:  3 Loss:  2.983386993408203
# Processing batch from row 8192 to 8704: (512, 7)
# Epochs:  3 Loss:  3.0010340213775635
# Processing batch from row 8704 to 9216: (512, 7)
# Epochs:  3 Loss:  2.984341859817505
# Processing batch from row 9216 to 9728: (512, 7)
# Epochs:  3 Loss:  3.0261688232421875
# Processing batch from row 9728 to 10240: (512, 7)
# Epochs:  3 Loss:  3.0620765686035156
# Processing batch from row 10240 to 10752: (512, 7)
# Epochs:  3 Loss:  3.1547672748565674
# Processing batch from row 10752 to 11264: (512, 7)
# Epochs:  3 Loss:  3.0533676147460938
# Processing batch from row 11264 to 11776: (512, 7)
# Epochs:  3 Loss:  2.930619239807129
# Processing batch from row 11776 to 12288: (512, 7)
# Epochs:  3 Loss:  2.9533722400665283
# Processing batch from row 12288 to 12800: (512, 7)
# Epochs:  3 Loss:  2.96061110496521
# Processing batch from row 12800 to 13312: (512, 7)
# Epochs:  3 Loss:  3.1525943279266357
# Processing batch from row 13312 to 13824: (512, 7)
# Epochs:  3 Loss:  2.978808641433716
# Processing batch from row 13824 to 14336: (512, 7)
# Epochs:  3 Loss:  2.9671499729156494
# Processing batch from row 14336 to 14848: (512, 7)
# Epochs:  3 Loss:  2.920413017272949
# Processing batch from row 14848 to 15360: (512, 7)
# Epochs:  3 Loss:  2.9329936504364014
# Processing batch from row 15360 to 15872: (512, 7)
# Epochs:  3 Loss:  2.9165337085723877
# Processing batch from row 15872 to 16384: (512, 7)
# Epochs:  3 Loss:  2.902599573135376
# Processing batch from row 16384 to 16896: (512, 7)
# Epochs:  3 Loss:  2.9454104900360107
# Processing batch from row 16896 to 17408: (512, 7)
# Epochs:  3 Loss:  3.225797414779663
# Processing batch from row 17408 to 17920: (512, 7)
# Epochs:  3 Loss:  3.1476669311523438
# Processing batch from row 17920 to 18432: (512, 7)
# Epochs:  3 Loss:  3.056720018386841
# Processing batch from row 18432 to 18944: (512, 7)
# Epochs:  3 Loss:  2.9789676666259766
# Processing batch from row 18944 to 19456: (512, 7)
# Epochs:  3 Loss:  2.9723196029663086
# Processing batch from row 19456 to 19968: (512, 7)
# Epochs:  3 Loss:  2.988942861557007
# Processing batch from row 19968 to 20480: (512, 7)
# Epochs:  3 Loss:  2.984158754348755
# Processing batch from row 20480 to 20992: (512, 7)
# Epochs:  3 Loss:  2.9570472240448
# Processing batch from row 20992 to 21504: (512, 7)
# Epochs:  3 Loss:  2.985422134399414
# Processing batch from row 21504 to 22016: (512, 7)
# Epochs:  3 Loss:  3.1928045749664307
# Processing batch from row 22016 to 22528: (512, 7)
# Epochs:  3 Loss:  3.1465113162994385
# Processing batch from row 22528 to 23040: (512, 7)
# Epochs:  3 Loss:  3.017493486404419
# Processing batch from row 23040 to 23552: (512, 7)
# Epochs:  3 Loss:  2.977534294128418
# Processing batch from row 23552 to 24064: (512, 7)
# Epochs:  3 Loss:  2.999098777770996
# Processing batch from row 24064 to 24576: (512, 7)
# Epochs:  3 Loss:  2.9445104598999023
# Processing batch from row 24576 to 25088: (512, 7)
# Epochs:  3 Loss:  2.970618486404419
# Processing batch from row 25088 to 25600: (512, 7)
# Epochs:  3 Loss:  2.9865005016326904
# Processing batch from row 25600 to 26112: (512, 7)
# Epochs:  3 Loss:  2.989518404006958
# Processing batch from row 26112 to 26624: (512, 7)
# Epochs:  3 Loss:  3.0026562213897705
# Processing batch from row 26624 to 27136: (512, 7)
# Epochs:  3 Loss:  3.0606343746185303
# Processing batch from row 27136 to 27648: (512, 7)
# Epochs:  3 Loss:  3.0455236434936523
# Processing batch from row 27648 to 28160: (512, 7)
# Epochs:  3 Loss:  3.0380191802978516
# Processing batch from row 28160 to 28672: (512, 7)
# Epochs:  3 Loss:  3.156946897506714
# Processing batch from row 28672 to 29184: (512, 7)
# Epochs:  3 Loss:  3.219121217727661
# Processing batch from row 29184 to 29696: (512, 7)
# Epochs:  3 Loss:  3.0326602458953857
# Processing batch from row 29696 to 30208: (512, 7)
# Epochs:  3 Loss:  2.966615676879883
# Processing batch from row 30208 to 30720: (512, 7)
# Epochs:  3 Loss:  3.18276047706604
# Processing batch from row 30720 to 31232: (512, 7)
# Epochs:  3 Loss:  3.199789047241211
# Processing batch from row 31232 to 31744: (512, 7)
# Epochs:  3 Loss:  3.036597490310669
# Processing batch from row 31744 to 32256: (512, 7)
# Epochs:  3 Loss:  3.0334742069244385
# Processing batch from row 32256 to 32768: (512, 7)
# Epochs:  3 Loss:  3.0575387477874756
# Processing batch from row 32768 to 33280: (512, 7)
# Epochs:  3 Loss:  3.136216878890991
# Processing batch from row 33280 to 33792: (512, 7)
# Epochs:  3 Loss:  3.001722574234009
# Processing batch from row 33792 to 34304: (512, 7)
# Epochs:  3 Loss:  2.988344430923462
# Processing batch from row 34304 to 34816: (512, 7)
# Epochs:  3 Loss:  3.009141206741333
# Processing batch from row 34816 to 35328: (512, 7)
# Epochs:  3 Loss:  3.0801455974578857
# Processing batch from row 35328 to 35840: (512, 7)
# Epochs:  3 Loss:  3.047311544418335
# Processing batch from row 35840 to 36352: (512, 7)
# Epochs:  3 Loss:  2.9816930294036865
# Processing batch from row 36352 to 36864: (512, 7)
# Epochs:  3 Loss:  2.935293436050415
# Processing batch from row 36864 to 37376: (512, 7)
# Epochs:  3 Loss:  2.9379050731658936
# Processing batch from row 37376 to 37888: (512, 7)
# Epochs:  3 Loss:  2.9504897594451904
# Processing batch from row 37888 to 38400: (512, 7)
# Epochs:  3 Loss:  2.9394776821136475
# Processing batch from row 38400 to 38912: (512, 7)
# Epochs:  3 Loss:  2.9959888458251953
# Processing batch from row 38912 to 39424: (512, 7)
# Epochs:  3 Loss:  2.9974794387817383
# Processing batch from row 39424 to 39936: (512, 7)
# Epochs:  3 Loss:  2.986612558364868
# Processing batch from row 39936 to 40448: (512, 7)
# Epochs:  3 Loss:  2.9698827266693115
# Processing batch from row 40448 to 40960: (512, 7)
# Epochs:  3 Loss:  2.998765707015991
# Processing batch from row 40960 to 41472: (512, 7)
# Epochs:  3 Loss:  3.041285753250122
# Processing batch from row 41472 to 41984: (512, 7)
# Epochs:  3 Loss:  3.030870199203491
# Processing batch from row 41984 to 42496: (512, 7)
# Epochs:  3 Loss:  3.0851333141326904
# Processing batch from row 42496 to 43008: (512, 7)
# Epochs:  3 Loss:  3.1448910236358643
# Processing batch from row 43008 to 43520: (512, 7)
# Epochs:  3 Loss:  3.0089681148529053
# Processing batch from row 43520 to 44032: (512, 7)
# Epochs:  3 Loss:  2.987151861190796
# Processing batch from row 44032 to 44544: (512, 7)
# Epochs:  3 Loss:  3.0402004718780518
# Processing batch from row 44544 to 45056: (512, 7)
# Epochs:  3 Loss:  2.9990415573120117
# Processing batch from row 45056 to 45568: (512, 7)
# Epochs:  3 Loss:  2.913919448852539
# Processing batch from row 45568 to 46080: (512, 7)
# Epochs:  3 Loss:  3.056990385055542
# Processing batch from row 46080 to 46592: (512, 7)
# Epochs:  3 Loss:  2.9700374603271484
# Processing batch from row 46592 to 47104: (512, 7)
# Epochs:  3 Loss:  2.9520251750946045
# Processing batch from row 47104 to 47616: (512, 7)
# Epochs:  3 Loss:  2.895258903503418
# Processing batch from row 47616 to 48128: (512, 7)
# Epochs:  3 Loss:  2.9090120792388916
# Processing batch from row 48128 to 48640: (512, 7)
# Epochs:  3 Loss:  2.9631125926971436
# Processing batch from row 48640 to 49152: (512, 7)
# Epochs:  3 Loss:  2.9968440532684326
# Processing batch from row 49152 to 49664: (512, 7)
# Epochs:  3 Loss:  3.019361734390259
# Processing batch from row 49664 to 50176: (512, 7)
# Epochs:  3 Loss:  3.0041677951812744
# Processing batch from row 50176 to 50688: (512, 7)
# Epochs:  3 Loss:  3.012411117553711
# Processing batch from row 50688 to 51200: (512, 7)
# Epochs:  3 Loss:  2.9625027179718018
# Processing batch from row 51200 to 51712: (512, 7)
# Epochs:  3 Loss:  2.9989712238311768
# Processing batch from row 51712 to 52224: (512, 7)
# Epochs:  3 Loss:  2.9075725078582764
# Processing batch from row 52224 to 52736: (512, 7)
# Epochs:  3 Loss:  2.937175989151001
# Processing batch from row 52736 to 53248: (512, 7)
# Epochs:  3 Loss:  2.9906511306762695
# Processing batch from row 53248 to 53760: (512, 7)
# Epochs:  3 Loss:  2.9859912395477295
# Processing batch from row 53760 to 54272: (512, 7)
# Epochs:  3 Loss:  3.035743474960327
# Processing batch from row 54272 to 54784: (512, 7)
# Epochs:  3 Loss:  3.036566734313965
# Processing batch from row 54784 to 55296: (512, 7)
# Epochs:  3 Loss:  3.0252344608306885
# Processing batch from row 55296 to 55808: (512, 7)
# Epochs:  3 Loss:  2.966974973678589
# Processing batch from row 55808 to 56320: (512, 7)
# Epochs:  3 Loss:  3.040628433227539
# Processing batch from row 56320 to 56832: (512, 7)
# Epochs:  3 Loss:  3.0360326766967773
# Processing batch from row 56832 to 57344: (512, 7)
# Epochs:  3 Loss:  3.0145692825317383
# Processing batch from row 57344 to 57856: (512, 7)
# Epochs:  3 Loss:  2.941180944442749
# Processing batch from row 57856 to 58368: (512, 7)
# Epochs:  3 Loss:  2.935218095779419
# Processing batch from row 58368 to 58880: (512, 7)
# Epochs:  3 Loss:  2.9679858684539795
# Processing batch from row 58880 to 59392: (512, 7)
# Epochs:  3 Loss:  2.9348080158233643
# Processing batch from row 59392 to 59904: (512, 7)
# Epochs:  3 Loss:  2.9362103939056396
# Processing batch from row 59904 to 60416: (512, 7)
# Epochs:  3 Loss:  2.9177157878875732
# Processing batch from row 60416 to 60928: (512, 7)
# Epochs:  3 Loss:  2.8921058177948
# Processing batch from row 60928 to 61440: (512, 7)
# Epochs:  3 Loss:  2.879754066467285
# Processing batch from row 61440 to 61952: (512, 7)
# Epochs:  3 Loss:  2.878809928894043
# Processing batch from row 61952 to 62464: (512, 7)
# Epochs:  3 Loss:  2.914391279220581
# Processing batch from row 62464 to 62976: (512, 7)
# Epochs:  3 Loss:  2.9359357357025146
# Processing batch from row 62976 to 63488: (512, 7)
# Epochs:  3 Loss:  2.9875705242156982
# Processing batch from row 63488 to 64000: (512, 7)
# Epochs:  3 Loss:  2.972590208053589
# Processing batch from row 64000 to 64512: (512, 7)
# Epochs:  3 Loss:  2.985769033432007
# Processing batch from row 64512 to 65024: (512, 7)
# Epochs:  3 Loss:  3.016299247741699
# Processing batch from row 65024 to 65536: (512, 7)
# Epochs:  3 Loss:  2.967646598815918
# Processing batch from row 65536 to 66048: (512, 7)
# Epochs:  3 Loss:  2.975756883621216
# Processing batch from row 66048 to 66560: (512, 7)
# Epochs:  3 Loss:  2.9889211654663086
# Processing batch from row 66560 to 67072: (512, 7)
# Epochs:  3 Loss:  2.9168403148651123
# Processing batch from row 67072 to 67584: (512, 7)
# Epochs:  3 Loss:  2.924405097961426
# Processing batch from row 67584 to 68096: (512, 7)
# Epochs:  3 Loss:  2.902550458908081
# Processing batch from row 68096 to 68608: (512, 7)
# Epochs:  3 Loss:  2.7891290187835693
# Processing batch from row 68608 to 69120: (512, 7)
# Epochs:  3 Loss:  2.818852186203003
# Processing batch from row 69120 to 69632: (512, 7)
# Epochs:  3 Loss:  2.87532901763916
# Processing batch from row 69632 to 70144: (512, 7)
# Epochs:  3 Loss:  2.8400118350982666
# Processing batch from row 70144 to 70656: (512, 7)
# Epochs:  3 Loss:  2.906796455383301
# Processing batch from row 70656 to 71168: (512, 7)
# Epochs:  3 Loss:  2.9360859394073486
# Processing batch from row 71168 to 71680: (512, 7)
# Epochs:  3 Loss:  3.0971152782440186
# Processing batch from row 71680 to 72192: (512, 7)
# Epochs:  3 Loss:  3.072962522506714
# Processing batch from row 72192 to 72704: (512, 7)
# Epochs:  3 Loss:  2.8782217502593994
# Processing batch from row 72704 to 73216: (512, 7)
# Epochs:  3 Loss:  3.105358362197876
# Processing batch from row 73216 to 73728: (512, 7)
# Epochs:  3 Loss:  3.096325159072876
# Processing batch from row 73728 to 74240: (512, 7)
# Epochs:  3 Loss:  3.046962022781372
# Processing batch from row 74240 to 74752: (512, 7)
# Epochs:  3 Loss:  3.1985321044921875
# Processing batch from row 74752 to 75264: (512, 7)
# Epochs:  3 Loss:  3.314584732055664
# Processing batch from row 75264 to 75776: (512, 7)
# Epochs:  3 Loss:  3.0593793392181396
# Processing batch from row 75776 to 76288: (512, 7)
# Epochs:  3 Loss:  2.881666421890259
# Processing batch from row 76288 to 76800: (512, 7)
# Epochs:  3 Loss:  2.9115123748779297
# Processing batch from row 76800 to 77312: (512, 7)
# Epochs:  3 Loss:  3.1639363765716553
# Processing batch from row 77312 to 77824: (512, 7)
# Epochs:  3 Loss:  3.0773258209228516
# Processing batch from row 77824 to 78336: (512, 7)
# Epochs:  3 Loss:  3.1981189250946045
# Processing batch from row 78336 to 78848: (512, 7)
# Epochs:  3 Loss:  3.053436040878296
# Processing batch from row 78848 to 79360: (512, 7)
# Epochs:  3 Loss:  3.1229588985443115
# Processing batch from row 79360 to 79872: (512, 7)
# Epochs:  3 Loss:  3.0798158645629883
# Processing batch from row 79872 to 80384: (512, 7)
# Epochs:  3 Loss:  3.0377540588378906
# Processing batch from row 80384 to 80896: (512, 7)
# Epochs:  3 Loss:  3.0485219955444336
# Processing batch from row 80896 to 81408: (512, 7)
# Epochs:  3 Loss:  3.0646982192993164
# Processing batch from row 81408 to 81920: (512, 7)
# Epochs:  3 Loss:  3.0913846492767334
# Processing batch from row 81920 to 82432: (512, 7)
# Epochs:  3 Loss:  3.13611102104187
# Processing batch from row 82432 to 82944: (512, 7)
# Epochs:  3 Loss:  3.052945137023926
# Processing batch from row 82944 to 83456: (512, 7)
# Epochs:  3 Loss:  3.0528619289398193
# Processing batch from row 83456 to 83968: (512, 7)
# Epochs:  3 Loss:  2.993511915206909
# Processing batch from row 83968 to 84480: (512, 7)
# Epochs:  3 Loss:  3.0351831912994385
# Processing batch from row 84480 to 84992: (512, 7)
# Epochs:  3 Loss:  2.988393545150757
# Processing batch from row 84992 to 85504: (512, 7)
# Epochs:  3 Loss:  2.9855124950408936
# Processing batch from row 85504 to 86016: (512, 7)
# Epochs:  3 Loss:  2.9890668392181396
# Processing batch from row 86016 to 86528: (512, 7)
# Epochs:  3 Loss:  2.9992291927337646
# Processing batch from row 86528 to 87040: (512, 7)
# Epochs:  3 Loss:  3.0254459381103516
# Processing batch from row 87040 to 87552: (512, 7)
# Epochs:  3 Loss:  3.055635452270508
# Processing batch from row 87552 to 88064: (512, 7)
# Epochs:  3 Loss:  3.0513994693756104
# Processing batch from row 88064 to 88576: (512, 7)
# Epochs:  3 Loss:  3.0131683349609375
# Processing batch from row 88576 to 89088: (512, 7)
# Epochs:  3 Loss:  2.993589162826538
# Processing batch from row 89088 to 89600: (512, 7)
# Epochs:  3 Loss:  3.007277727127075
# Processing batch from row 89600 to 90112: (512, 7)
# Epochs:  3 Loss:  3.0008504390716553
# Processing batch from row 90112 to 90624: (512, 7)
# Epochs:  3 Loss:  2.9829037189483643
# Processing batch from row 90624 to 91136: (512, 7)
# Epochs:  3 Loss:  2.971923828125
# Processing batch from row 91136 to 91648: (512, 7)
# Epochs:  3 Loss:  2.9890851974487305
# Processing batch from row 91648 to 92160: (512, 7)
# Epochs:  3 Loss:  2.962322235107422
# Processing batch from row 92160 to 92672: (512, 7)
# Epochs:  3 Loss:  2.976273775100708
# Processing batch from row 92672 to 93184: (512, 7)
# Epochs:  3 Loss:  2.9578752517700195
# Processing batch from row 93184 to 93696: (512, 7)
# Epochs:  3 Loss:  2.96476149559021
# Processing batch from row 93696 to 94208: (512, 7)
# Epochs:  3 Loss:  2.967845916748047
# Processing batch from row 94208 to 94720: (512, 7)
# Epochs:  3 Loss:  2.9482524394989014
# Processing batch from row 94720 to 95232: (512, 7)
# Epochs:  3 Loss:  2.941664695739746
# Processing batch from row 95232 to 95744: (512, 7)
# Epochs:  3 Loss:  2.9762284755706787
# Processing batch from row 95744 to 96256: (512, 7)
# Epochs:  3 Loss:  2.9505674839019775
# Processing batch from row 96256 to 96768: (512, 7)
# Epochs:  3 Loss:  2.930391550064087
# Processing batch from row 96768 to 97053: (285, 7)
# Epochs:  3 Loss:  2.912191390991211
# loss mean:  3.026733869000485

# %%
total_rows = df_cleaned.shape[0]
batch_size = 512
prob_ls = np.zeros(df.shape[0])
count_p = 0
import matplotlib.pyplot as plt
for batch_start in range(0, total_rows, batch_size):
      batch_end = min(batch_start + batch_size, total_rows)
      str_ls = []
      for x in range(batch_start, batch_end):
          ls0 = []
          for col in col1:
            v = df.loc[x, col]
            v = str(v)
            ls0.append(v)
          str_ls.append(ls0)
      data_x = np.array(str_ls)
      print(f"Processing batch from row {batch_start} to {batch_end}: {data_x.shape}")

      x_train = []
      for row in str_ls:
          ls0 = []
          for item in row:
              ls0.append(dict.get(item, 0))
          x_train.append(ls0)

      x_train = torch.from_numpy(np.array(x_train))
      y_train = x_train[:, 1:]
      x_train = x_train[:, :-1]
      prob_distri = torch.softmax(tfm(x_train[:,:]),dim=-1)
      prob_distri.shape
      for k in range(1,len(col1)-2):
        prob_distri = torch.softmax(tfm(x_train[:,0:k]),dim=-1)
        for x in range(prob_distri.shape[0]):
            prob0 = 0
            prob0=prob_distri[x,k-1,y_train[x,k-1]].item()
            prob_ls[batch_start + x]+=prob0
        #print(k)
      print(count_p)
      count_p += 1
plt.scatter(range(len(prob_ls)),prob_ls,s=1)
        #get minum prob index to locate least likely combination across data

print(np.argmin(prob_ls))
        #df.loc[294]
# Out:
# Processing batch from row 0 to 512: (512, 7)
# 0
# Processing batch from row 512 to 1024: (512, 7)
# 1
# Processing batch from row 1024 to 1536: (512, 7)
# 2
# Processing batch from row 1536 to 2048: (512, 7)
# 3
# Processing batch from row 2048 to 2560: (512, 7)
# 4
# Processing batch from row 2560 to 3072: (512, 7)
# 5
# Processing batch from row 3072 to 3584: (512, 7)
# 6
# Processing batch from row 3584 to 4096: (512, 7)
# 7
# Processing batch from row 4096 to 4608: (512, 7)
# 8
# Processing batch from row 4608 to 5120: (512, 7)
# 9
# Processing batch from row 5120 to 5632: (512, 7)
# 10
# Processing batch from row 5632 to 6144: (512, 7)
# 11
# Processing batch from row 6144 to 6656: (512, 7)
# 12
# Processing batch from row 6656 to 7168: (512, 7)
# 13
# Processing batch from row 7168 to 7680: (512, 7)
# 14
# Processing batch from row 7680 to 8192: (512, 7)
# 15
# Processing batch from row 8192 to 8704: (512, 7)
# 16
# Processing batch from row 8704 to 9216: (512, 7)
# 17
# Processing batch from row 9216 to 9728: (512, 7)
# 18
# Processing batch from row 9728 to 10240: (512, 7)
# 19
# Processing batch from row 10240 to 10752: (512, 7)
# 20
# Processing batch from row 10752 to 11264: (512, 7)
# 21
# Processing batch from row 11264 to 11776: (512, 7)
# 22
# Processing batch from row 11776 to 12288: (512, 7)
# 23
# Processing batch from row 12288 to 12800: (512, 7)
# 24
# Processing batch from row 12800 to 13312: (512, 7)
# 25
# Processing batch from row 13312 to 13824: (512, 7)
# 26
# Processing batch from row 13824 to 14336: (512, 7)
# 27
# Processing batch from row 14336 to 14848: (512, 7)
# 28
# Processing batch from row 14848 to 15360: (512, 7)
# 29
# Processing batch from row 15360 to 15872: (512, 7)
# 30
# Processing batch from row 15872 to 16384: (512, 7)
# 31
# Processing batch from row 16384 to 16896: (512, 7)
# 32
# Processing batch from row 16896 to 17408: (512, 7)
# 33
# Processing batch from row 17408 to 17920: (512, 7)
# 34
# Processing batch from row 17920 to 18432: (512, 7)
# 35
# Processing batch from row 18432 to 18944: (512, 7)
# 36
# Processing batch from row 18944 to 19456: (512, 7)
# 37
# Processing batch from row 19456 to 19968: (512, 7)
# 38
# Processing batch from row 19968 to 20480: (512, 7)
# 39
# Processing batch from row 20480 to 20992: (512, 7)
# 40
# Processing batch from row 20992 to 21504: (512, 7)
# 41
# Processing batch from row 21504 to 22016: (512, 7)
# 42
# Processing batch from row 22016 to 22528: (512, 7)
# 43
# Processing batch from row 22528 to 23040: (512, 7)
# 44
# Processing batch from row 23040 to 23552: (512, 7)
# 45
# Processing batch from row 23552 to 24064: (512, 7)
# 46
# Processing batch from row 24064 to 24576: (512, 7)
# 47
# Processing batch from row 24576 to 25088: (512, 7)
# 48
# Processing batch from row 25088 to 25600: (512, 7)
# 49
# Processing batch from row 25600 to 26112: (512, 7)
# 50
# Processing batch from row 26112 to 26624: (512, 7)
# 51
# Processing batch from row 26624 to 27136: (512, 7)
# 52
# Processing batch from row 27136 to 27648: (512, 7)
# 53
# Processing batch from row 27648 to 28160: (512, 7)
# 54
# Processing batch from row 28160 to 28672: (512, 7)
# 55
# Processing batch from row 28672 to 29184: (512, 7)
# 56
# Processing batch from row 29184 to 29696: (512, 7)
# 57
# Processing batch from row 29696 to 30208: (512, 7)
# 58
# Processing batch from row 30208 to 30720: (512, 7)
# 59
# Processing batch from row 30720 to 31232: (512, 7)
# 60
# Processing batch from row 31232 to 31744: (512, 7)
# 61
# Processing batch from row 31744 to 32256: (512, 7)
# 62
# Processing batch from row 32256 to 32768: (512, 7)
# 63
# Processing batch from row 32768 to 33280: (512, 7)
# 64
# Processing batch from row 33280 to 33792: (512, 7)
# 65
# Processing batch from row 33792 to 34304: (512, 7)
# 66
# Processing batch from row 34304 to 34816: (512, 7)
# 67
# Processing batch from row 34816 to 35328: (512, 7)
# 68
# Processing batch from row 35328 to 35840: (512, 7)
# 69
# Processing batch from row 35840 to 36352: (512, 7)
# 70
# Processing batch from row 36352 to 36864: (512, 7)
# 71
# Processing batch from row 36864 to 37376: (512, 7)
# 72
# Processing batch from row 37376 to 37888: (512, 7)
# 73
# Processing batch from row 37888 to 38400: (512, 7)
# 74
# Processing batch from row 38400 to 38912: (512, 7)
# 75
# Processing batch from row 38912 to 39424: (512, 7)
# 76
# Processing batch from row 39424 to 39936: (512, 7)
# 77
# Processing batch from row 39936 to 40448: (512, 7)
# 78
# Processing batch from row 40448 to 40960: (512, 7)
# 79
# Processing batch from row 40960 to 41472: (512, 7)
# 80
# Processing batch from row 41472 to 41984: (512, 7)
# 81
# Processing batch from row 41984 to 42496: (512, 7)
# 82
# Processing batch from row 42496 to 43008: (512, 7)
# 83
# Processing batch from row 43008 to 43520: (512, 7)
# 84
# Processing batch from row 43520 to 44032: (512, 7)
# 85
# Processing batch from row 44032 to 44544: (512, 7)
# 86
# Processing batch from row 44544 to 45056: (512, 7)
# 87
# Processing batch from row 45056 to 45568: (512, 7)
# 88
# Processing batch from row 45568 to 46080: (512, 7)
# 89
# Processing batch from row 46080 to 46592: (512, 7)
# 90
# Processing batch from row 46592 to 47104: (512, 7)
# 91
# Processing batch from row 47104 to 47616: (512, 7)
# 92
# Processing batch from row 47616 to 48128: (512, 7)
# 93
# Processing batch from row 48128 to 48640: (512, 7)
# 94
# Processing batch from row 48640 to 49152: (512, 7)
# 95
# Processing batch from row 49152 to 49664: (512, 7)
# 96
# Processing batch from row 49664 to 50176: (512, 7)
# 97
# Processing batch from row 50176 to 50688: (512, 7)
# 98
# Processing batch from row 50688 to 51200: (512, 7)
# 99
# Processing batch from row 51200 to 51712: (512, 7)
# 100
# Processing batch from row 51712 to 52224: (512, 7)
# 101
# Processing batch from row 52224 to 52736: (512, 7)
# 102
# Processing batch from row 52736 to 53248: (512, 7)
# 103
# Processing batch from row 53248 to 53760: (512, 7)
# 104
# Processing batch from row 53760 to 54272: (512, 7)
# 105
# Processing batch from row 54272 to 54784: (512, 7)
# 106
# Processing batch from row 54784 to 55296: (512, 7)
# 107
# Processing batch from row 55296 to 55808: (512, 7)
# 108
# Processing batch from row 55808 to 56320: (512, 7)
# 109
# Processing batch from row 56320 to 56832: (512, 7)
# 110
# Processing batch from row 56832 to 57344: (512, 7)
# 111
# Processing batch from row 57344 to 57856: (512, 7)
# 112
# Processing batch from row 57856 to 58368: (512, 7)
# 113
# Processing batch from row 58368 to 58880: (512, 7)
# 114
# Processing batch from row 58880 to 59392: (512, 7)
# 115
# Processing batch from row 59392 to 59904: (512, 7)
# 116
# Processing batch from row 59904 to 60416: (512, 7)
# 117
# Processing batch from row 60416 to 60928: (512, 7)
# 118
# Processing batch from row 60928 to 61440: (512, 7)
# 119
# Processing batch from row 61440 to 61952: (512, 7)
# 120
# Processing batch from row 61952 to 62464: (512, 7)
# 121
# Processing batch from row 62464 to 62976: (512, 7)
# 122
# Processing batch from row 62976 to 63488: (512, 7)
# 123
# Processing batch from row 63488 to 64000: (512, 7)
# 124
# Processing batch from row 64000 to 64512: (512, 7)
# 125
# Processing batch from row 64512 to 65024: (512, 7)
# 126
# Processing batch from row 65024 to 65536: (512, 7)
# 127
# Processing batch from row 65536 to 66048: (512, 7)
# 128
# Processing batch from row 66048 to 66560: (512, 7)
# 129
# Processing batch from row 66560 to 67072: (512, 7)
# 130
# Processing batch from row 67072 to 67584: (512, 7)
# 131
# Processing batch from row 67584 to 68096: (512, 7)
# 132
# Processing batch from row 68096 to 68608: (512, 7)
# 133
# Processing batch from row 68608 to 69120: (512, 7)
# 134
# Processing batch from row 69120 to 69632: (512, 7)
# 135
# Processing batch from row 69632 to 70144: (512, 7)
# 136
# Processing batch from row 70144 to 70656: (512, 7)
# 137
# Processing batch from row 70656 to 71168: (512, 7)
# 138
# Processing batch from row 71168 to 71680: (512, 7)
# 139
# Processing batch from row 71680 to 72192: (512, 7)
# 140
# Processing batch from row 72192 to 72704: (512, 7)
# 141
# Processing batch from row 72704 to 73216: (512, 7)
# 142
# Processing batch from row 73216 to 73728: (512, 7)
# 143
# Processing batch from row 73728 to 74240: (512, 7)
# 144
# Processing batch from row 74240 to 74752: (512, 7)
# 145
# Processing batch from row 74752 to 75264: (512, 7)
# 146
# Processing batch from row 75264 to 75776: (512, 7)
# 147
# Processing batch from row 75776 to 76288: (512, 7)
# 148
# Processing batch from row 76288 to 76800: (512, 7)
# 149
# Processing batch from row 76800 to 77312: (512, 7)
# 150
# Processing batch from row 77312 to 77824: (512, 7)
# 151
# Processing batch from row 77824 to 78336: (512, 7)
# 152
# Processing batch from row 78336 to 78848: (512, 7)
# 153
# Processing batch from row 78848 to 79360: (512, 7)
# 154
# Processing batch from row 79360 to 79872: (512, 7)
# 155
# Processing batch from row 79872 to 80384: (512, 7)
# 156
# Processing batch from row 80384 to 80896: (512, 7)
# 157
# Processing batch from row 80896 to 81408: (512, 7)
# 158
# Processing batch from row 81408 to 81920: (512, 7)
# 159
# Processing batch from row 81920 to 82432: (512, 7)
# 160
# Processing batch from row 82432 to 82944: (512, 7)
# 161
# Processing batch from row 82944 to 83456: (512, 7)
# 162
# Processing batch from row 83456 to 83968: (512, 7)
# 163
# Processing batch from row 83968 to 84480: (512, 7)
# 164
# Processing batch from row 84480 to 84992: (512, 7)
# 165
# Processing batch from row 84992 to 85504: (512, 7)
# 166
# Processing batch from row 85504 to 86016: (512, 7)
# 167
# Processing batch from row 86016 to 86528: (512, 7)
# 168
# Processing batch from row 86528 to 87040: (512, 7)
# 169
# Processing batch from row 87040 to 87552: (512, 7)
# 170
# Processing batch from row 87552 to 88064: (512, 7)
# 171
# Processing batch from row 88064 to 88576: (512, 7)
# 172
# Processing batch from row 88576 to 89088: (512, 7)
# 173
# Processing batch from row 89088 to 89600: (512, 7)
# 174
# Processing batch from row 89600 to 90112: (512, 7)
# 175
# Processing batch from row 90112 to 90624: (512, 7)
# 176
# Processing batch from row 90624 to 91136: (512, 7)
# 177
# Processing batch from row 91136 to 91648: (512, 7)
# 178
# Processing batch from row 91648 to 92160: (512, 7)
# 179
# Processing batch from row 92160 to 92672: (512, 7)
# 180
# Processing batch from row 92672 to 93184: (512, 7)
# 181
# Processing batch from row 93184 to 93696: (512, 7)
# 182
# Processing batch from row 93696 to 94208: (512, 7)
# 183
# Processing batch from row 94208 to 94720: (512, 7)
# 184
# Processing batch from row 94720 to 95232: (512, 7)
# 185
# Processing batch from row 95232 to 95744: (512, 7)
# 186
# Processing batch from row 95744 to 96256: (512, 7)
# 187
# Processing batch from row 96256 to 96768: (512, 7)
# 188
# Processing batch from row 96768 to 97053: (285, 7)
# 189
# 84174

# %%
df_test = df2 

for x in range(df_test.shape[0]):
    date_str = df_test.loc[x, "Policy_start_date"]
    year = datetime.strptime(date_str, "%Y-%m-%d").year
    df_test.loc[x, "Policy_start_date"] = year

    age = int(df_test.loc[x, "Age"])
    if age < 10:
        df_test.loc[x, "Age"] = "<10"
    else:
        for start in range(10, 100, 10):
            if start <= age < start + 10:
                df_test.loc[x, "Age"] = f"{start}-{start + 10}"
                break
        else:
            df_test.loc[x, "Age"] = "90-100"

    ap = df_test.loc[x, "Annual_premium"]
    if ap < 100:
        df_test.loc[x, "Annual_premium"] = "ap<100"
    else:
        for start in range(100, 2000, 100):
            if start <= ap < start + 100:
                df_test.loc[x, "Annual_premium"] = f"ap{start}-{start + 100}"
                break
        else:
            df_test.loc[x, "Annual_premium"] = "ap1900-2000"

    claims = df_test.loc[x, "Claim_amount"]
    if claims < 1000:
        df_test.loc[x, "Claim_amount"] = "<1000"
    elif claims < 5000:
        df_test.loc[x, "Claim_amount"] = "1000<5000"
    elif claims < 10000:
        df_test.loc[x, "Claim_amount"] = "5000<10000"
    elif claims < 50000:
        df_test.loc[x, "Claim_amount"] = "10000<50000"
    else:
        df_test.loc[x, "Claim_amount"] = "50000+"
# Out:
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/2525734607.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '40-50' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_test.loc[x, "Age"] = f"{start}-{start + 10}"
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/2525734607.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ap1400-1500' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_test.loc[x, "Annual_premium"] = f"ap{start}-{start + 100}"
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/2525734607.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '50000+' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_test.loc[x, "Claim_amount"] = "50000+"

# %%
total_rows = df_test.shape[0]
batch_size = 512
prob_ls = np.zeros(df_test.shape[0])
count_p = 0
import matplotlib.pyplot as plt

for batch_start in range(0, total_rows, batch_size):
    batch_end = min(batch_start + batch_size, total_rows)
    str_ls = []
    for x in range(batch_start, batch_end):
        ls0 = []
        for col in col1:
            v = df_test.loc[x, col]
            v = str(v)
            ls0.append(v)
        str_ls.append(ls0)
    data_x = np.array(str_ls)
    print(f"Processing batch from row {batch_start} to {batch_end}: {data_x.shape}")

    x_train = []
    for row in str_ls:
        ls0 = []
        for item in row:
            ls0.append(dict.get(item, 0))
        x_train.append(ls0)

    x_train = torch.from_numpy(np.array(x_train))
    y_train = x_train[:, 1:]
    x_train = x_train[:, :-1]
    prob_distri = torch.softmax(tfm(x_train[:, :]), dim=-1)
    prob_distri.shape
    for k in range(1, len(col1) - 2):
        prob_distri = torch.softmax(tfm(x_train[:, 0:k]), dim=-1)
        for x in range(prob_distri.shape[0]):
            prob0 = 0
            prob0 = prob_distri[x, k - 1, y_train[x, k - 1]].item()
            prob_ls[batch_start + x] += prob0
        # print(k)
    print(count_p)
    count_p += 1

plt.scatter(range(len(prob_ls)), prob_ls, s=1)
# Get minimum probability index to locate the least likely combination across data
print(np.argmin(prob_ls))
# Out:
# Processing batch from row 0 to 512: (512, 7)
# 0
# Processing batch from row 512 to 1015: (503, 7)
# 1
# 496

# %%
plt.scatter(range(len(prob_ls)),prob_ls,s=1)
plt.xlabel("index_row")
plt.ylabel("sum_probability_predicted")
plt.axhline(y=0.1783, color='r', linestyle='--', label='250 Outliers Line')
#plt.axhline(y=0.75, color='black', linestyle='--', label='500 Outliers Line')
plt.legend()
plt.show()

# %%
sorted(prob_ls)[250]
# Out:
# 0.17839848027506378

# %%
df2["prob_transformer"] = prob_ls
df2["is_fraud"] = 0
for x in range(df2.shape[0]):
    if df2.loc[x,"prob_transformer"]<0.178:
        df2.loc[x,"is_fraud"] = "Y"
    else:
        df2.loc[x,"is_fraud"] = "N"
# Out:
# /var/folders/0q/22f144kx4dn41cw151l589xh0000gn/T/ipykernel_85003/1343366407.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.loc[x,"is_fraud"] = "N"

# %%
df2[(df2["fraud_reported"] == "N") & (df2["is_fraud"] == "N")]
# Out:
#       Unnamed: 0 Policy_start_date    Age Annual_premium  Vehicle_year  \
# 4              5              2014  40-50    ap1500-1600          2009
# 6              7              2000  30-40    ap1300-1400          2012
# 7              8              1990  30-40    ap1100-1200          2015
# 8              9              1997  30-40    ap1400-1500          2012
# 9             10              2011  40-50    ap1300-1400          1996
# ...          ...               ...    ...            ...           ...
# 1008        1009              2001  20-30    ap1200-1300          2012
# 1009        1010              2007  30-40    ap1300-1400          1996
# 1010        1011              1991  30-40    ap1300-1400          2006
# 1011        1012              2014  40-50    ap1400-1500          2015
# 1012        1013              2003  30-40    ap1300-1400          1996
#
#      Claim_amount  Vehicle_risk_type  Area fraud_reported  prob_transformer  \
# 4      5000<10000                  2   1.0              N          0.220517
# 6          50000+                  2   1.0              N          0.219268
# 7          50000+                  2   1.0              N          0.209343
# 8     10000<50000                  2   0.0              N          0.211765
# 9     10000<50000                  2   1.0              N          0.197977
# ...           ...                ...   ...            ...               ...
# 1008       50000+                  2   1.0              N          0.180926
# 1009   5000<10000                  2   0.0              N          0.225009
# 1010       50000+                  2   0.0              N          0.201497
# 1011       50000+                  2   0.0              N          0.227688
# 1012       50000+                  2   0.0              N          0.222334
#
#      is_fraud
# 4           N
# 6           N
# 7           N
# 8           N
# 9           N
# ...       ...
# 1008        N
# 1009        N
# 1010        N
# 1011        N
# 1012        N
#
# [591 rows x 11 columns]

# %%
correct = 0
for x in range(df2.shape[0]):
    if df2.loc[x,"fraud_reported"] == df2.loc[x,"is_fraud"]:
        correct+=1
print("accuracy: ", correct/df2.shape[0])
# Out:
# accuracy:  0.6571428571428571

# %%
plt.scatter(range(len(prob_ls)),df2["prob_transformer"],s=1,c=df2["fraud_reported"].map({"Y": 'red', "N": 'blue'}))
plt.xlabel("index_row")
plt.ylabel("sum_probability_predicted")
plt.axhline(y=0.1783, color='r', linestyle='--', label='250 Outliers Line')
#plt.axhline(y=0.75, color='black', linestyle='--', label='500 Outliers Line')
plt.legend()
plt.show()

# %%
df2
# Out:
#       Unnamed: 0 Policy_start_date    Age Annual_premium  Vehicle_year  \
# 0              1              2014  40-50    ap1400-1500          2004
# 1              2              2006  40-50    ap1100-1200          2007
# 2              3              2000  20-30    ap1400-1500          2007
# 3              4              1990  40-50    ap1400-1500          2014
# 4              5              2014  40-50    ap1500-1600          2009
# ...          ...               ...    ...            ...           ...
# 1010        1011              1991  30-40    ap1300-1400          2006
# 1011        1012              2014  40-50    ap1400-1500          2015
# 1012        1013              2003  30-40    ap1300-1400          1996
# 1013        1014              2011  60-70    ap1300-1400          1998
# 1014        1015              1996  60-70      ap700-800          2007
#
#      Claim_amount  Vehicle_risk_type  Area fraud_reported  prob_transformer  \
# 0          50000+                  2   1.0              Y          0.218869
# 1      5000<10000                  2   1.0              Y          0.210992
# 2     10000<50000                  3   1.0              N          0.029678
# 3          50000+                  2   1.0              Y          0.181069
# 4      5000<10000                  2   1.0              N          0.220517
# ...           ...                ...   ...            ...               ...
# 1010       50000+                  2   0.0              N          0.201497
# 1011       50000+                  2   0.0              N          0.227688
# 1012       50000+                  2   0.0              N          0.222334
# 1013  10000<50000                  2   1.0              N          0.160460
# 1014   5000<10000                  2   0.0              N          0.169915
#
#      is_fraud
# 0           F
# 1           F
# 2           T
# 3           F
# 4           F
# ...       ...
# 1010        F
# 1011        F
# 1012        F
# 1013        T
# 1014        T
#
# [1015 rows x 11 columns]
